# %%
import requests
import networkx as nx
import matplotlib.pyplot as plt
from ipywidgets import widgets

# %% [markdown]
# ### API Key and Example Origin Destination pair

# %%
# HERE Maps API credentials
HERE_API_KEY = "_ndbqeeFBj4CO61Ygrbm0duIGwVPbWIm6Mp8_GvgD9A"

# Example usage
origin = "45.77031773045832,4.797116290985852"
destination = "45.76469668270752,4.955347272776582"

# %% [markdown]
# ### Vechile Parameters

# %%
vehicle_params = {
    "mass": 1190,  # kg
    "wheel_radius": 0.2848,  # meters
    "transmission_ratio": 5.763,
    "transmission_efficiency": 0.95,
    "drive_efficiency": 0.85,
    "a0": 125.73,  # N
    "a1": 1.72,  # N/(m/s)
    "a2": 0.58,  # N/(m/s)^2
    "motor_min_torque": -50,  # Nm
    "motor_max_torque": 200,  # Nm
    "acceleration": 1.5,  # m/s²
    "air_density": 1.225  # kg/m^3
}

# %% [markdown]
# ### Retriving routing data from API

# %%
def get_route_data(origin, destination, routing_mode):
    url = "https://router.hereapi.com/v8/routes"
    params = {
        "apikey": HERE_API_KEY,
        "transportMode": "car",
        "origin": origin,
        "destination": destination,
        "routingMode": routing_mode,  # Specify routing mode
        "return": "summary,polyline"
    }
    response = requests.get(url, params=params)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code} - {response.text}")
        raise Exception(f"HERE Maps API request failed with status code {response.status_code}")

# Data for the sample origin destination pair:
fastest_route = get_route_data(origin, destination, routing_mode="fast")
shortest_route = get_route_data(origin, destination, routing_mode="short")

# %%
print(fastest_route)
# Out:
# {'routes': [{'id': '980f9aa6-dd4b-462f-a722-4890b4fc7b30', 'sections': [{'id': '75e86f1a-4c86-4fdb-bf6b-f07967bb2263', 'type': 'vehicle', 'departure': {'time': '2025-03-01T11:53:29+01:00', 'place': {'type': 'place', 'location': {'lat': 45.7703299, 'lng': 4.79704}, 'originalLocation': {'lat': 45.7703177, 'lng': 4.7971162}}}, 'arrival': {'time': '2025-03-01T12:17:05+01:00', 'place': {'type': 'place', 'location': {'lat': 45.7647268, 'lng': 4.956095}, 'originalLocation': {'lat': 45.7646966, 'lng': 4.9553472}}}, 'summary': {'duration': 1416, 'length': 16897, 'baseDuration': 1240}, 'polyline': 'BG0lzp3Cgn5kJkcnQoVvM4SnLgjBrT0hCriB4S__Oo7CnkB00Fvb0sEvlB81F_OwoCjIssBrO4pC3mBo_F7GkhB3DsOrJ4hBvM4mB3X4_B_T46BzKopBnLs7B3DwbT4IrEgyBnBkmB7BozBAkDToLnBk1B_EkgE7B4XjD4_BT4hBnB8aU4XUkmBkDw5BgKk6BsE4S0FkX0P46BwMwlBsT8uB0FwMsJ0PsJsOsEoGkIwM4hBkwBoLgPokBk1BwWopBgKkX8L8fsgC86F4I0ZsEkN8GsT8GgUoG8VgFsT8GopBkDkcoB4XA0ZnBgZ3DsiBnGgjB3IkhB7G8VvHsTjN4c7Q0erd4wBrY8kBrOgUzegoBjhBsnBvoCoxCjc8fz1C8gDjSkSnLsOriBkmB7Q4SrOoQvvBk1BrT0U_Y0Z7f4c_d0Z_JkI_O8L7asY74B0tB7uB4mB7a0UrsBokB_8D8lD3c4XnLsJ3NoL_lCo4B35Eo-D74BwvB3wBsnBniCg3B__EA_EAjcsE_oDwRzyBsJ3DU3DUrJoBT4ITwRTwHTsJnBwWAwCvC4mBnBokBnBoanBgenBsTnB8QAwMnB8uB7BsiBnB0jBAgPAsOUgKoBoQ8BwbUoL8B4cUgPoBkXoB8QsE82CkDwlBsEkwBUwHwCgPwCoQUgF8BoL0F0egF4mBwC4XkDwqBoBgtBT4_BTwWTo9BAwHA8QTkSA4SAwWTozBTgtBAkIA4NTsdnBgtBjDgmCsOT8VnBAnQiLd', 'transport': {'mode': 'car'}}]}]}

# %% [markdown]
# ## Main Energy Consumption Model Based on [G. De Nunzio, L. Thibault and A. Sciarretta, "A model-based eco-routing strategy for electric vehicles in large urban networks," 2016 IEEE 19th International Conference on Intelligent Transportation Systems (ITSC), Rio de Janeiro, Brazil, 2016, pp. 2301-2306, doi: 10.1109/ITSC.2016.7795927.](https://ieeexplore.ieee.org/document/7795927)

# %%
from geopy.distance import geodesic

def compute_energy_consumption(route_sections, vehicle_params):
    energy_consumption = []
    gravity = 9.81  # m/s²
    def compute_section_energy(length, speed, grade, acceleration=0):
        rolling_force = vehicle_params["a0"] + vehicle_params["a1"] * speed + vehicle_params["a2"] * speed**2
        slope_force = vehicle_params["mass"] * gravity * grade
        inertial_force = vehicle_params["mass"] * acceleration

        # Total force at wheels
        total_force = rolling_force + slope_force + inertial_force

        # Motor torque and power
        wheel_radius = vehicle_params["wheel_radius"]
        transmission_ratio = vehicle_params["transmission_ratio"]
        transmission_efficiency = vehicle_params["transmission_efficiency"]

        if total_force >= 0:
            motor_torque = total_force * wheel_radius / (transmission_ratio * transmission_efficiency)
        else:
            motor_torque = total_force * wheel_radius * transmission_efficiency / transmission_ratio

        motor_speed = speed * transmission_ratio / wheel_radius
        motor_power = motor_torque * motor_speed

        # Battery power demand considering efficiency
        drive_efficiency = vehicle_params["drive_efficiency"]
        if motor_power >= 0:
            battery_power = motor_power / drive_efficiency
        else:
            battery_power = motor_power * drive_efficiency

        # Energy for this section (Wh)
        travel_time = length / speed if speed > 0 else 0
        energy = (battery_power * travel_time) / 3600
        return energy

    if all(isinstance(section, tuple) for section in route_sections):
        for i in range(len(route_sections) - 1):
            start_coord = route_sections[i]
            end_coord = route_sections[i + 1]

            length = geodesic(start_coord, end_coord).meters
            speed = 10  # Assume constant speed (10 m/s ~ 36 km/h)
            grade = 0  # Flat terrain assumption

            # Energy computation
            energy = compute_section_energy(length, speed, grade)
            energy_consumption.append(energy)
    else:
        for section in route_sections:
            length = section["summary"]["length"]
            duration = section["summary"]["duration"]
            speed = length / duration if duration > 0 else 0
            grade = section.get("grade", 0)
            acceleration = section.get("acceleration", 0)

            # Energy computation
            energy = compute_section_energy(length, speed, grade, acceleration)
            energy_consumption.append(energy)

    return energy_consumption

# %% [markdown]
# ### Finding closest node in the graph for the given geo co-ordinates

# %%
def find_closest_node(graph, target_coords):
    closest_node = None
    min_distance = float('inf')

    for node in graph.nodes:
        # Calculate the geodesic distance between the node and target coordinates
        distance = geodesic(node, target_coords).meters
        if distance < min_distance:
            min_distance = distance
            closest_node = node

    return closest_node

# %% [markdown]
# ### Computing route energy and conversion into relevant metrics

# %%
def compute_route_energy(route_sections, vehicle_params):
    energy_joules = compute_energy_consumption(route_sections, vehicle_params)
    energy_kwh = [energy / 3_600_000 for energy in energy_joules]  # Convert Joules to kWh
    return energy_kwh

# %% [markdown]
# ## Rebuilding the graph where weights of the path are based on the energy consumption for that section

# %%
import networkx as nx

def rebuild_graph_from_route_sections(route_sections, vehicle_params):
    new_graph = nx.DiGraph()

    # Compute energy consumption for each section
    energy_values = compute_energy_consumption(route_sections, vehicle_params)

    for i, section in enumerate(route_sections):
        try:
            start = (
                section["departure"]["place"]["location"]["lat"],
                section["departure"]["place"]["location"]["lng"]
            )
            end = (
                section["arrival"]["place"]["location"]["lat"],
                section["arrival"]["place"]["location"]["lng"]
            )

            # Use computed energy as the weight
            weight = energy_values[i] if i < len(energy_values) else INT_MAX

            # Add edge to the graph with energy as weight
            new_graph.add_edge(start, end, weight=weight)
        except KeyError as e:
            print(f"Error processing section: {e}")

    return new_graph

# %% [markdown]
# ### Comparing results for the sample Origin Destination Pair

# %%
def compare_routes(origin, destination, vehicle_params):
    print(f"Comparing routes from Origin: {origin} to Destination: {destination}")

    try:
        # Fetch fastest route data
        fastest_route = get_route_data(origin, destination, routing_mode="fast")
        fastest_energy = compute_route_energy(fastest_route["routes"][0]["sections"], vehicle_params)

        # Fetch shortest route data
        shortest_route = get_route_data(origin, destination, routing_mode="short")
        shortest_energy = compute_route_energy(shortest_route["routes"][0]["sections"], vehicle_params)

        # Rebuild the graph using shortest route data
        road_network = rebuild_graph_from_route_sections(shortest_route["routes"][0]["sections"],vehicle_params)

        # Find the custom route using the rebuilt graph
        origin_coords = tuple(map(float, origin.split(",")))
        destination_coords = tuple(map(float, destination.split(",")))
        origin_node = find_closest_node(road_network, origin_coords)
        destination_node = find_closest_node(road_network, destination_coords)

        custom_route_coords = nx.bellman_ford_path(road_network, source=origin_node, target=destination_node, weight="weight") #bellman_ford_algo
        custom_energy = compute_route_energy(custom_route_coords, vehicle_params)

        # Summarize energy consumption
        energy_comparison = {
            "Fastest Route Energy (kWh)": sum(fastest_energy),
            "Shortest Route Energy (kWh)": sum(shortest_energy),
            "Custom Route Energy (kWh)": sum(custom_energy),
        }

        # Calculate percentage savings for the custom route
        energy_comparison["Savings Compared to Fastest (%)"] = (
            (1 - energy_comparison["Custom Route Energy (kWh)"] / energy_comparison["Fastest Route Energy (kWh)"]) * 100
        )
        energy_comparison["Savings Compared to Shortest (%)"] = (
            (1 - energy_comparison["Custom Route Energy (kWh)"] / energy_comparison["Shortest Route Energy (kWh)"]) * 100
        )

        return energy_comparison

    except Exception as e:
        print(f"Error comparing routes: {e}")
        return None

# %%
comparison_results = compare_routes(origin, destination,vehicle_params)
print(comparison_results)
# Out:
# Comparing routes from Origin: 45.77031773045832,4.797116290985852 to Destination: 45.76469668270752,4.955347272776582
# {'Fastest Route Energy (kWh)': 0.0003696999344134835, 'Shortest Route Energy (kWh)': 0.00021702713550953703, 'Custom Route Energy (kWh)': 0.0002378172297459462, 'Savings Compared to Fastest (%)': 35.67290453452874, 'Savings Compared to Shortest (%)': -9.579490687926251}

# %%
data = {
    'Fastest Route Energy (kWh)': comparison_results['Fastest Route Energy (kWh)'],
    'Shortest Route Energy (kWh)': comparison_results['Shortest Route Energy (kWh)'],
    'Custom Route Energy (kWh)': comparison_results['Custom Route Energy (kWh)'],
    'Savings Compared to Fastest (%)': comparison_results['Savings Compared to Fastest (%)'],
    'Savings Compared to Shortest (%)': comparison_results['Savings Compared to Shortest (%)']
}
print(data)
# Out:
# {'Fastest Route Energy (kWh)': 0.0003696999344134835, 'Shortest Route Energy (kWh)': 0.00021702713550953703, 'Custom Route Energy (kWh)': 0.0002378172297459462, 'Savings Compared to Fastest (%)': 35.67290453452874, 'Savings Compared to Shortest (%)': -9.579490687926251}

# %% [markdown]
# ### Visualization of the results for a single pair of Origin Destination

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline


sns.set_theme(style="whitegrid")


energy_labels = ['Fastest Route', 'Shortest Route', 'Custom Route']
energy_values = [
    data['Fastest Route Energy (kWh)'],
    data['Shortest Route Energy (kWh)'],
    data['Custom Route Energy (kWh)']
]


savings_labels = ['Compared to Fastest', 'Compared to Shortest']
savings_values = [
    data['Savings Compared to Fastest (%)'],
    data['Savings Compared to Shortest (%)']
]


energy_colors = ['#d62728', '#1f77b4', '#2ca02c']  # Red, Blue, Green
savings_colors = ['#9467bd', '#ff7f0e']  # Purple, Orange


fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Plotting energy consumption
bars1 = axes[0].bar(energy_labels, energy_values, color=energy_colors, edgecolor='black', linewidth=1.2)
axes[0].set_title('Energy Consumption Comparison', fontsize=14, fontweight='bold')
axes[0].set_ylabel('Energy (kWh)', fontsize=12)
axes[0].tick_params(axis='x', rotation=15)

# Adding value labels inside bars
for bar in bars1:
    height = bar.get_height()
    axes[0].text(bar.get_x() + bar.get_width() / 2, height * 0.5,  # Position inside the bar
                 f"{height:.6f}", ha='center', va='center', fontsize=11, fontweight='bold', color='white')

# Plotting savings percentage
bars2 = axes[1].bar(savings_labels, savings_values, color=savings_colors, edgecolor='black', linewidth=1.2)
axes[1].set_title('Energy Savings Comparison', fontsize=14, fontweight='bold')
axes[1].set_ylabel('Savings (%)', fontsize=14)
axes[1].tick_params(axis='x', rotation=10)

# Adding value labels inside bars
for bar in bars2:
    height = bar.get_height()
    axes[1].text(bar.get_x() + bar.get_width() / 2, height * 0.5,  # Position inside the bar
                 f"{height:.2f}%", ha='center', va='center', fontsize=11, fontweight='bold', color='white')


plt.subplots_adjust(left=0.08, right=0.95, top=0.85, bottom=0.15, wspace=0.25)


plt.show()

# %%
# !pip install flexpolyline
# Out:
# Collecting flexpolyline
#   Downloading flexpolyline-0.1.0-py3-none-any.whl.metadata (4.5 kB)
# Downloading flexpolyline-0.1.0-py3-none-any.whl (7.1 kB)
# Installing collected packages: flexpolyline
# Successfully installed flexpolyline-0.1.0

# %%
import folium
import flexpolyline

# Decode polyline for routes
fastest_coordinates = flexpolyline.decode(fastest_route["routes"][0]["sections"][0]["polyline"])
shortest_coordinates = flexpolyline.decode(shortest_route["routes"][0]["sections"][0]["polyline"])
# custom_route_coords = flexpolyline.decode(route_sections[0]["polyline"])

# Convert the computed custom route into coordinate pairs
# custom_route_coords = [(lat, lng) for lat, lng in custom_route_coords]

# Create a map centered around the origin
start_lat, start_lng = fastest_coordinates[0]
map_obj = folium.Map(location=[start_lat, start_lng], zoom_start=14)

# Add the fastest route to the map
folium.PolyLine(locations=fastest_coordinates, color="blue", weight=5, tooltip="Fastest Route").add_to(map_obj)

# Add the shortest route to the map
folium.PolyLine(locations=shortest_coordinates, color="orange", weight=10, tooltip="Shortest Route").add_to(map_obj)

# Add the custom route to the map
# folium.PolyLine(locations=custom_route_coords, color="purple", weight=5, tooltip="Custom Route").add_to(map_obj)

# Add markers for origin and destination
folium.Marker(location=fastest_coordinates[0], popup="Origin", icon=folium.Icon(color="green")).add_to(map_obj)

folium.Marker(location=fastest_coordinates[-1], popup="Destination", icon=folium.Icon(color="red")).add_to(map_obj)

# Print the origin and destination
print(f"Origin coordinates: {origin}")
print(f"Destination coordinates: {destination}")

# Display the map
map_obj
# Out:
# Origin coordinates: 45.77031773045832,4.797116290985852
# Destination coordinates: 45.76469668270752,4.955347272776582
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f59eaf6fbdba269873306c2263132d11 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f59eaf6fbdba269873306c2263132d11&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f59eaf6fbdba269873306c2263132d11 = L.map(
#                 &quot;map_f59eaf6fbdba269873306c2263132d11&quot;,
#                 {
#                     center: [45.77033, 4.79704],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ab8f4297dcda000581dfab5cac14c33a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ab8f4297dcda000581dfab5cac14c33a.addTo(map_f59eaf6fbdba269873306c2263132d11);
#
#
#             var poly_line_2f1080971825f6eefc4795f02e4c1160 = L.polyline(
#                 [[45.77033, 4.79704], [45.77078, 4.79678], [45.77112, 4.79658], [45.77142, 4.7964], [45.77198, 4.79609], [45.77303, 4.79554], [45.77333, 4.79538], [45.77363, 4.79521], [45.77428, 4.79483], [45.77457, 4.79466], [45.77486, 4.79449], [45.77496, 4.79442], [45.77507, 4.79432], [45.77512, 4.79438], [45.77523, 4.79451], [45.77533, 4.79462], [45.7755, 4.79482], [45.77575, 4.79511], [45.77587, 4.79526], [45.77603, 4.79546], [45.77621, 4.79576], [45.77625, 4.79583], [45.77636, 4.79611], [45.77639, 4.79626], [45.77641, 4.79644], [45.77642, 4.79671], [45.77667, 4.79689], [45.77676, 4.79694], [45.7777, 4.79734], [45.77805, 4.79751], [45.77823, 4.79769], [45.77863, 4.7982], [45.77954, 4.79941], [45.77988, 4.79994], [45.78024, 4.80047], [45.78051, 4.80081], [45.78084, 4.80062], [45.
, 4.88255], [45.79146, 4.88287], [45.79097, 4.88351], [45.79044, 4.88414], [45.78928, 4.88544], [45.78883, 4.88595], [45.78746, 4.8875], [45.78717, 4.88779], [45.78699, 4.88802], [45.78644, 4.88863], [45.78617, 4.88893], [45.78594, 4.88919], [45.78518, 4.89004], [45.78487, 4.89037], [45.78447, 4.89078], [45.78396, 4.89124], [45.78348, 4.89165], [45.78332, 4.89178], [45.78308, 4.89197], [45.78265, 4.89236], [45.78174, 4.89309], [45.78099, 4.89371], [45.78056, 4.89404], [45.77985, 4.89462], [45.77785, 4.89625], [45.77739, 4.89663], [45.77721, 4.89678], [45.7769 ...

# %%
# !pip install osmnx
# Out:
# Collecting osmnx
#   Downloading osmnx-2.0.1-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: geopandas>=1.0 in /usr/local/lib/python3.11/dist-packages (from osmnx) (1.0.1)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.11/dist-packages (from osmnx) (3.4.2)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.11/dist-packages (from osmnx) (1.26.4)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.11/dist-packages (from osmnx) (2.2.2)
# Requirement already satisfied: requests>=2.27 in /usr/local/lib/python3.11/dist-packages (from osmnx) (2.32.3)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.11/dist-packages (from osmnx) (2.0.7)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from geopandas>=1.0->osmnx) (0.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from geopandas>=1.0->osmnx) (24.2)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from geopandas>=1.0->osmnx) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4->osmnx) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4->osmnx) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4->osmnx) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27->osmnx) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27->osmnx) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27->osmnx) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27->osmnx) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4->osmnx) (1.17.0)
# Downloading osmnx-2.0.1-py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.6/99.6 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: osmnx
# Successfully installed osmnx-2.0.1

# %% [markdown]
# ### Downloading the road network for Lyon,France

# %%
import osmnx as ox
import networkx as nx


# 1. Download the road network for Lyon, France (driving network)
G = ox.graph_from_place("Lyon, France", network_type="drive")

# 2. Print the number of nodes and edges in the network
num_nodes = len(G.nodes)
num_edges = len(G.edges)
print("Total number of nodes:", num_nodes)
print("Total number of edges:", num_edges)
# Out:
# Total number of nodes: 4176
# Total number of edges: 8253

# %% [markdown]
# ### Writing all data in a file in the format ["node", "latitude", "longitude"]

# %%
import csv
with open('node_coordinates.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    # Write header row
    writer.writerow(["node", "latitude", "longitude"])

    # Write each node's coordinates
    for node, data in G.nodes(data=True):
        writer.writerow([node, data['y'], data['x']])

# %%
import pandas as pd
from tabulate import tabulate

# Read the CSV file
df = pd.read_csv('/content/node_coordinates.csv')

# Print the DataFrame in a tabular format using tabulate
print(tabulate(df, headers='keys', tablefmt='pretty'))
# Out:
# +------+---------------+------------+-----------+
# |      |     node      |  latitude  | longitude |
# +------+---------------+------------+-----------+
# |  0   |   143403.0    | 45.7338265 | 4.8775406 |
# |  1   |   143408.0    | 45.734208  | 4.8763392 |
# |  2   |   143412.0    | 45.738481  | 4.8628174 |
# |  3   |   143413.0    | 45.7378325 | 4.8648442 |
# |  4   |   143415.0    | 45.7405718 | 4.8638746 |
# |  5   |   143416.0    | 45.7423937 | 4.8648175 |
# |  6   |   143417.0    | 45.7434152 | 4.8653524 |
# |  7   |   143418.0    |  45.74512  | 4.8662118 |
# |  8   |   143421.0    | 45.7445879 | 4.8683205 |
# |  9   |   143435.0    | 45.7408693 | 4.862994  |
# |  10  |   143439.0    | 45.7435071 | 4.8537112 |
# |  11  |   195222.0    | 45.7572235 | 4.836902  |
# |  12  |   195228.0    | 45.7592213 | 4.8296142 |
# |  13  |   195231.0    | 45.7533116 | 4.8337706 |
# |  14  |   195232.0    | 45.7530715 | 4.8339066 |
# |  15  |   195234.0    | 45.7512129 | 4.8386402 |
# |  16  |   195235.0    | 45.7503096 | 4.8401349 |
# |  17  |   195236.0    | 45.7497245 | 4.8411203 |
# |  18  |   195237.0    | 45.7487134 | 4.8428234 |
# |  19  |   195239.0    | 45.7473632 | 4.8451082 |
# |  20  |   195241.0    | 45.7452345 | 4.8488579 |
# |  21  |   195242.0    | 45.7455544 | 4.849161  |
# |  22  |   195244.0    | 45.7464263 | 4.8499842 |
# |  23  |   195246.0    | 45.7443892 | 4.8518925 |
# |  24  |   195249.0    | 45.749826  | 4.8521067 |
# |  25  |   195250.0    | 45.7510527 | 4.8481937 |
# |  26  |   195251.0    | 45.7521209 | 4.8466255 |
# |  27  |   195252.0    | 45.7538146 | 4.8440857 |
# |  28  |   195256.0    | 45.7478086 | 4.8336422 |
# |  29  |   195259.0    |  45.75104  | 4.8599184 |
# |  30  |   195261.0    | 45.7539262 | 4.861588  |
# |  31  |   195262.0    | 45.7499195 | 4.8604722 |
# |  32  |   195266.0    | 45.7500008 | 4.8644645 |
# |  33  |   195268.0    | 45.7507295 | 4.8650444 |
# |  34  |   195270.0    | 45.7515565 | 4.8653924 |
# |  35  |   195271.0    | 45.7512027 | 4.8685939 |
# |  36  |   195274.0    | 45.7489016 | 4.8681255 |
# |  37  |   195275.0    | 45.747923  | 4.8676335 |
# |  38  |   195276.0    | 45.7476254 | 4.8652133 |
# |  39  |   195277.0    | 45.7466235 | 4.8681383 |
# |  40  |   195279.0    | 45.7440532 | 4.8704734 |
# |  41  |   195282.0    | 45.7559836 | 4.8408271 |
# |  42  |   581678.0    | 45.7482219 | 4.8436512 |
# |  43  |   7300862.0   | 45.7448729 | 4.8732228 |
# |  44  |   7300867.0   | 45.743567  | 4.8728497 |
# |  45  |   7393914.0   | 45.7476418 | 4.7843656 |
# |  46  |   7393915.0   | 45.7486485 | 4.7864594 |
# |  47  |   7394428.0   | 45.7499404 | 4.7855199 |
# |  48  |   7394439.0   | 45.7502486 | 4.7853161 |
# |  49  |   7394456.0   | 45.7498732 | 4.7836769 |
# |  50  |   7394477.0   | 45.7497324 | 4.7833614 |
# |  51  |   7394819.0   | 45.7534813 | 4.7928393 |
# |  52  |   7394820.0   | 45.7543996 | 4.7960631 |
# |  53  |   7394824.0   | 45.7530219 | 4.7956143 |
# |  54  |   7394832.0   | 45.7502509 | 4.7922391 |
# |  55  |   7394910.0   | 45.7563978 | 4.7976889 |
# |  56  |   7394925.0   | 45.7563465 | 4.7969598 |
# |  57  |   7395110.0   | 45.7506014 | 4.789071  |
# |  58  |   7395306.0   | 45.7475404 | 4.7787814 |
# |  59  |   7395468.0   | 45.7471441 | 4.7777147 |
# |  60  |   7469500.0   | 45.7686227 | 4.8382347 |
# |  61  |   7469501.0   | 45.7635164 | 4.8384656 |
# |  62  |   7470129.0   | 45.7601706 | 4.8379366 |
# |  63  |   7470130.0   | 45.7590967 | 4.8376296 |
# |  64  |   8089058.0   | 45.7499755 | 4.7809702 |
# |  65  |   8089059.0   | 45.7520908 | 4.7818971 |
# |  66  |   8206700.0   | 45.7492119 | 4.7945168 |
# |  67  |   8207493.0   | 45.7565471 | 4.7948185 |
# |  68  |   8207506.0   | 45.7562492 | 4.7961256 |
# |  69  |   8209560.0   | 45.7532588 | 4.7897326 |
# |  70  |   8209633.0   | 45.7526317 | 4.7894828 |
# |  71  |   8358135.0   | 45.759994  | 4.8410595 |
# |  72  |   8433662.0   | 45.7561257 | 4.8058577 |
# |  73  |   8433684.0   | 45.7562573 | 4.8029272 |
# |  74  |   8433808.0   | 45.7571138 | 4.8103452 |
# |  75  |   8433940.0   | 45.756665  | 4.8122871 |
# |  76  |   8434031.0   | 45.7556909 | 4.8158781 |
# |  77  |   8434042.0   | 45.7562442 | 4.8175251 |
# |  78  |   8592437.0   | 45.7547781 | 4.8124207 |
# |  79  |   8593279.0   | 45.7554866 | 4.808692  |
# |  80  |   8593425.0   | 45.7533309 | 4.8046912 |
# |  81  |   8698701.0   | 45.7467112 | 4.7827817 |
# |  82  |   8876507.0   | 45.7523229 | 4.8032796 |
# |  83  |   8876576.0   | 45.7502241 | 4.8067121 |
# |  84  |   8876586.0   | 45.7500367 | 4.8074259 |
# |  85  |   8876604.0   | 45.7517939 | 4.8088834 |
# |  86  |   8877429.0   | 45.7548461 | 4.8070982 |
# |  87  |   9213739.0   | 45.7591471 | 4.7914238 |
# |  88  |   9213756.0   | 45.7582282 | 4.7950489 |
# |  89  |   9214618.0   | 45.7468084 | 4.8367805 |
# |  90  |   9214708.0   | 45.7434686 | 4.8472228 |
# |  91  |   9214909.0   | 45.739582  | 4.8657274 |
# |  92  |   9214911.0   | 45.740699  | 4.8662998 |
# |  93  |   9214915.0   | 45.7403478 | 4.8677313 |
# |  94  |   9214919.0   | 45.7402118 | 4.8647954 |
# |  95  |   9249417.0   | 45.7542301 | 4.813149  |
# |  96  |   9249808.0   | 45.7509067 | 4.814648  |
# |  97  |   9249817.0   | 45.751851  | 4.8166536 |
# |  98  |   9250428.0   | 45.7523243 | 4.8194793 |
# |  99  |   9250674.0   | 45.7515721 | 4.8203026 |
# | 100  |   9257184.0   | 45.7549555 | 4.7961739 |
# | 101  |   9257186.0   | 45.754831  | 4.796148  |
# | 102  |   9257214.0   | 45.7558414 | 4.7967569 |
# | 103  |   9257226.0   | 45.7549225 | 4.7963214 |
# | 104  |   9257232.0   | 45.7548122 | 4.7962694 |
# | 105  |   9259186.0   | 45.7550783 | 4.8027468 |
# | 106  |   9259681.0   | 45.7539592 | 4.798071  |
# | 107  |  13383951.0   | 45.7475571 | 4.829905  |
# | 108  |  13383978.0   | 45.750961  | 4.822422  |
# | 109  |  13445139.0   | 45.7638554 | 4.8021362 |
# | 110  |  15856749.0   | 45.726678  | 4.8308411 |
# | 111  |  15925416.0   | 45.7207743 | 4.8422624 |
# | 112  |  15925418.0   | 45.7188458 | 4.842448  |
# | 113  |  15925438.0   |  45.75044  | 4.8498574 |
# | 114  |  15925440.0   | 45.7474912 | 4.8575887 |
# | 115  |  15925442.0   | 45.7429311 | 4.8561536 |
# | 116  |  15925446.0   | 45.7520873 | 4.8522377 |
# | 117  |  15925447.0   | 45.7527626 | 4.8503431 |
# | 118  |  15925451.0   | 45.7470428 | 4.8389361 |
# | 119  |  15925452.0   | 45.747555  | 4.840187  |
# | 120  |  16050062.0   | 45.7687957 | 4.845017  |
# | 121  |  16564346.0   | 45.7474128 | 4.8292752 |
# | 122  |  16564347.0   | 45.7478591 | 4.8281977 |
# | 123  |  16564349.0   | 45.7487811 | 4.8275162 |
# | 124  |  16564350.0   | 45.7484401 | 4.8286825 |
# | 125  |  16564353.0   | 45.748185  | 4.8295178 |
# | 126  |  16564357.0   | 45.7453577 | 4.8275811 |
# | 127  |  16564364.0   | 45.7341628 | 4.8186749 |
# | 128  |  16564365.0   | 45.7343406 | 4.818207  |
# | 129  |  16566895.0   | 45.7509331 | 4.8240371 |
# | 130  |  16566897.0   | 45.7516818 | 4.8245761 |
# | 131  |  16566904.0   | 45.7509664 | 4.8238288 |
# | 132  |  16566907.0   | 45.7502329 | 4.8228671 |
# | 133  |  16566908.0   | 45.7500813 | 4.8234345 |
# | 134  |  16566910.0   | 45.750535  | 4.8253525 |
# | 135  |  18232178.0   | 45.7412123 | 4.8642064 |
# | 136  |  18232179.0   | 45.7418806 | 4.866909  |
# | 137  |  18232180.0   | 45.7414477 | 4.8686265 |
# | 138  |  18232182.0   | 45.7409462 | 4.8687934 |
# | 139  |  18232183.0   | 45.7423891 | 4.8693965 |
# | 140  |  18232184.0   | 45.7407099 | 4.8702469 |
# | 141  |  18232186.0   | 45.7429093 | 4.8627181 |
# | 142  |  18232187.0   | 45.743922  | 4.8632375 |
# | 143  |  18697376.0   | 45.7460096 | 4.8592361 |
# | 144  |  18697378.0   | 45.7445866 | 4.8610502 |
# | 145  |  18697383.0   | 45.746761  | 4.8610095 |
# | 146  |  18697385.0   | 45.7473069 | 4.8479935 |
# | 147  |  18697389.0   | 45.7442457 | 4.8619612 |
# | 148  |  18697393.0   | 45.743639  | 4.8593847 |
# | 149  |  18697395.0   | 45.7434554 | 4.8609411 |
# | 150  |  18697397.0   | 45.7487505 | 4.8493673 |
# | 151  |  18697400.0   | 45.7495702 | 4.8495986 |
# | 152  |  18697402.0   | 45.745755  | 4.860755  |
# | 153  |  18697408.0   | 45.7481923 | 4.852514  |
# | 154  |  18697411.0   | 45.7488769 | 4.8477527 |
# | 155  |  18697415.0   | 45.7490737 | 4.8535145 |
# | 156  |  18697420.0   | 45.7474319 | 4.8487486 |
# | 157  |  21510475.0   | 45.7451198 | 4.8628417 |
# | 158  |  21510476.0   | 45.7583732 | 4.814232  |
# | 159  |  21510484.0   | 45.7593492 | 4.8142795 |
# | 160  |  21510486.0   | 45.7604161 | 4.8127615 |
# | 161  |  21510487.0   | 45.7611407 | 4.8151319 |
# | 162  |  21510488.0   | 45.7579984 | 4.8138187 |
# | 163  |  21510489.0   | 45.7573236 | 4.8151861 |
# | 164  |  21510491.0   | 45.7597357 | 4.8162518 |
# | 165  |  21510495.0   | 45.7620666 | 4.8214752 |
# | 166  |  21595834.0   | 45.7458744 | 4.8636016 |
# | 167  |  21595835.0   | 45.7456909 | 4.8641958 |
# | 168  |  21597584.0   | 45.7593921 | 4.8339755 |
# | 169  |  21597586.0   | 45.7586241 | 4.8346598 |
# | 170  |  21597587.0   | 45.7587315 | 4.8339372 |
# | 171  |  21597588.0   | 45.7588254 | 4.8332588 |
# | 172  |  21597589.0   | 45.7594706 | 4.8333692 |
# | 173  |  21597590.0   | 45.7595415 | 4.8328379 |
# | 174  |  21597591.0   | 45.7602758 | 4.8340177 |
# | 175  |  21597593.0   | 45.760257  | 4.8334953 |
# | 176  |  21597802.0   | 45.7583959 | 4.8324815 |
# | 177  |  21597804.0   | 45.7582181 | 4.8331446 |
# | 178  |  21597808.0   | 45.7580404 | 4.8338067 |
# | 179  |  21600350.0   | 45.7417479 | 4.8621114 |
# | 180  |  21600353.0   | 45.7420953 | 4.8603776 |
# | 181  |  21600354.0   | 45.7416841 | 4.8605771 |
# | 182  |  21600355.0   | 45.7412663 | 4.8618457 |
# | 183  |  21604533.0   | 45.7504439 | 4.8449674 |
# | 184  |  21604549.0   | 45.7582043 | 4.8460967 |
# | 185  |  21604550.0   |  45.7609   | 4.8455267 |
# | 186  |  21604551.0   | 45.7626847 | 4.8451488 |
# | 187  |  21604552.0   | 45.7649846 | 4.8446619 |
# | 188  |  21604553.0   | 45.7667581 | 4.8442862 |
# | 189  |  21604556.0   | 45.7262571 | 4.8376404 |
# | 190  |  21604559.0   | 45.7282714 | 4.8376719 |
# | 191  |  21604576.0   | 45.7366748 | 4.8427516 |
# | 192  |  21604585.0   | 45.7371063 | 4.8503395 |
# | 193  |  21604592.0   | 45.7432416 | 4.8750688 |
# | 194  |  21604594.0   | 45.7427443 | 4.8785244 |
# | 195  |  21604596.0   | 45.7432042 | 4.8785346 |
# | 196  |  21604600.0   | 45.7429427 | 4.8793283 |
# | 197  |  21604601.0   | 45.7426562 | 4.8790562 |
# | 198  |  21674798.0   | 45.7680249 | 4.8451622 |
# | 199  |  21674799.0   | 45.7682339 | 4.8474368 |
# | 200  |  21674800.0   | 45.7675548 | 4.8475478 |
# | 201  |  21674801.0   | 45.7673528 | 4.845289  |
# | 202  |  21674802.0   | 45.7627809 | 4.8461633 |
# | 203  |  21674803.0   | 45.762582  | 4.8440545 |
# | 204  |  21674804.0   | 45.7601492 | 4.8445299 |
# | 205  |  21674805.0   | 45.7767358 | 4.844018  |
# | 206  |  21674806.0   | 45.7758043 | 4.8460947 |
# | 207  |  21674807.0   | 45.7727826 | 4.8465804 |
# | 208  |  21674808.0   | 45.7709605 | 4.8469241 |
# | 209  |  21674809.0   | 45.7707524 | 4.8446477 |
# | 210  |  21674822.0   | 45.781646  | 4.8331573 |
# | 211  |  21674895.0   | 45.7690266 | 4.8472874 |
# | 212  |  21674896.0   | 45.7578238 | 4.8408138 |
# | 213  |  21674897.0   | 45.7578891 | 4.8417021 |
# | 214  |  21674898.0   | 45.7570497 | 4.8415986 |
# | 215  |  21674900.0   |  45.7569   | 4.8421021 |
# | 216  |  21674901.0   | 45.7560858 | 4.8420779 |
# | 217  |  21674903.0   | 45.7542619 | 4.8388921 |
# | 218  |  21674905.0   | 45.7507024 | 4.8394705 |
# | 219  |  21674906.0   | 45.7561594 | 4.8402914 |
# | 220  |  21674907.0   | 45.7460468 | 4.8362476 |
# | 221  |  21674908.0   | 45.7466304 | 4.8344027 |
# | 222  |  21674910.0   | 45.745655  | 4.8359796 |
# | 223  |  21674913.0   | 45.7389497 | 4.8304154 |
# | 224  |  21674914.0   | 45.7339456 | 4.8260612 |
# | 225  |  21674915.0   | 45.7337327 | 4.8237985 |
# | 226  |  21674920.0   | 45.7266239 | 4.8269349 |
# | 227  |  21696145.0   | 45.743844  | 4.8679321 |
# | 228  |  21696191.0   | 45.7428904 | 4.8674413 |
# | 229  |  21696192.0   | 45.7433125 | 4.869998  |
# | 230  |  21696193.0   | 45.7443632 | 4.8658309 |
# | 231  |  21702418.0   | 45.7411419 | 4.8754639 |
# | 232  |  21702423.0   | 45.7423386 | 4.8774303 |
# | 233  |  21702431.0   |  45.74172  | 4.8712629 |
# | 234  |  21702433.0   | 45.7420194 | 4.8690885 |
# | 235  |  21702435.0   | 45.7426754 | 4.8768588 |
# | 236  |  21702437.0   | 45.742044  | 4.877001  |
# | 237  |  21702438.0   | 45.7428296 | 4.8781327 |
# | 238  |  21702760.0   | 45.7365965 | 4.8695358 |
# | 239  |  21703544.0   | 45.738718  | 4.8671814 |
# | 240  |  21703552.0   | 45.7386229 | 4.8669562 |
# | 241  |  21703587.0   | 45.7396588 | 4.8758786 |
# | 242  |  21703589.0   | 45.7401909 | 4.8772168 |
# | 243  |  21703590.0   | 45.7401392 | 4.8773672 |
# | 244  |  21703591.0   | 45.7403037 | 4.8774743 |
# | 245  |  21703594.0   | 45.7388592 | 4.8760773 |
# | 246  |  21703595.0   | 45.7393228 | 4.8775623 |
# | 247  |  21703596.0   | 45.7396272 | 4.8785199 |
# | 248  |  21703598.0   | 45.7404719 | 4.8778836 |
# | 249  |  21704334.0   | 45.7388143 | 4.8791615 |
# | 250  |  21704335.0   | 45.7384733 | 4.8782266 |
# | 251  |  21704337.0   | 45.7370724 | 4.876234  |
# | 252  |  21704339.0   | 45.7368138 | 4.8772242 |
# | 253  |  21704340.0   | 45.7373794 | 4.8790919 |
# | 254  |  21704341.0   | 45.737913  | 4.8798531 |
# | 255  |  21704344.0   | 45.740866  | 4.8788459 |
# | 256  |  21704346.0   | 45.7392371 | 4.8802313 |
# | 257  |  21704347.0   |  45.73857  | 4.8807861 |
# | 258  |  21704348.0   | 45.7367551 | 4.8823168 |
# | 259  |  21704353.0   | 45.7434978 | 4.8732584 |
# | 260  |  21704354.0   |  45.74157  | 4.8721382 |
# | 261  |  21712143.0   |  45.74872  | 4.8579066 |
# | 262  |  21712144.0   | 45.7490411 | 4.8565013 |
# | 263  |  21714980.0   | 45.7341304 | 4.8763332 |
# | 264  |  21714981.0   | 45.7337884 | 4.8773943 |
# | 265  |  21715353.0   | 45.7424745 | 4.8800225 |
# | 266  |  21717905.0   | 45.7404414 | 4.8834406 |
# | 267  |  21717906.0   | 45.7396979 | 4.8840167 |
# | 268  |  21717907.0   | 45.7393388 | 4.8830001 |
# | 269  |  21717908.0   | 45.7395846 | 4.8826584 |
# | 270  |  21717913.0   | 45.7397469 | 4.8849764 |
# | 271  |  21717915.0   | 45.7390563 | 4.8859166 |
# | 272  |  21717916.0   | 45.737193  | 4.8857238 |
# | 273  |  21717918.0   | 45.7369623 | 4.8858749 |
# | 274  |  21717919.0   | 45.7361985 | 4.8862566 |
# | 275  |  21717927.0   | 45.7368011 | 4.8838603 |
# | 276  |  21717928.0   | 45.7373154 | 4.8841939 |
# | 277  |  21717929.0   | 45.7376654 | 4.8851479 |
# | 278  |  21717930.0   | 45.7373974 | 4.8855664 |
# | 279  |  21717931.0   | 45.7357646 | 4.8818902 |
# | 280  |  21717932.0   | 45.7358836 | 4.8831053 |
# | 281  |  21717933.0   | 45.7360866 | 4.8847094 |
# | 282  |  21717934.0   | 45.7361622 | 4.8833591 |
# | 283  |  21717939.0   | 45.7350296 | 4.8822101 |
# | 284  |  21717941.0   | 45.7340313 | 4.8846669 |
# | 285  |  21717942.0   | 45.7334695 | 4.8846553 |
# | 286  |  21717943.0   | 45.7345347 | 4.8846773 |
# | 287  |  21717946.0   | 45.7339191 | 4.882602  |
# | 288  |  21717953.0   | 45.7366471 | 4.8778909 |
# | 289  |  21717954.0   | 45.7366169 | 4.8780116 |
# | 290  |  21717956.0   | 45.7361684 | 4.8800138 |
# | 291  |  21718264.0   | 45.7369859 | 4.8765721 |
# | 292  |  21718288.0   | 45.7340232 | 4.8776564 |
# | 293  |  21718291.0   | 45.7337903 | 4.8826354 |
# | 294  |  21718297.0   | 45.7333753 | 4.8830293 |
# | 295  |  21729400.0   | 45.7371669 | 4.8836662 |
# | 296  |  21729405.0   | 45.7361242 | 4.8802309 |
# | 297  |  21789166.0   | 45.7433855 | 4.8524615 |
# | 298  |  21850766.0   | 45.7391211 | 4.8642282 |
# | 299  |  21851032.0   | 45.7396427 | 4.8621402 |
# | 300  |  21852320.0   | 45.7388528 | 4.8653566 |
# | 301  |  21852322.0   | 45.7393682 | 4.8632697 |
# | 302  |  21852326.0   | 45.7381824 | 4.8637444 |
# | 303  |  21855792.0   | 45.7388639 | 4.8616021 |
# | 304  |  21992644.0   | 45.7410308 | 4.8585883 |
# | 305  |  21992645.0   | 45.7398643 | 4.8597221 |
# | 306  |  21992646.0   | 45.740218  | 4.8598813 |
# | 307  |  21992709.0   | 45.7420369 | 4.8592518 |
# | 308  |  21992712.0   | 45.7400439 | 4.8579502 |
# | 309  |  21992798.0   | 45.7423993 | 4.858138  |
# | 310  |  21992835.0   | 45.7467649 | 4.8647511 |
# | 311  |  21992836.0   | 45.7465233 | 4.864623  |
# | 312  |  21992964.0   | 45.7477782 | 4.8682372 |
# | 313  |  21992980.0   | 45.7485368 | 4.862575  |
# | 314  |  21992981.0   | 45.7463492 | 4.8622169 |
# | 315  |  21992995.0   | 45.7477448 | 4.8634284 |
# | 316  |  21992996.0   | 45.7476128 | 4.8639398 |
# | 317  |  21993013.0   | 45.7478703 | 4.8624662 |
# | 318  |  21993015.0   | 45.7473442 | 4.8650544 |
# | 319  |  21993017.0   | 45.7482154 | 4.8635068 |
# | 320  |  22145874.0   | 45.7517032 | 4.8215743 |
# | 321  |  22146035.0   | 45.7520696 | 4.8208984 |
# | 322  |  22147748.0   | 45.7522673 | 4.820474  |
# | 323  |  22156849.0   | 45.7521207 | 4.8163524 |
# | 324  |  22156869.0   | 45.7519724 | 4.8167897 |
# | 325  |  22158975.0   | 45.7518907 | 4.8165682 |
# | 326  |  22209228.0   | 45.7568222 | 4.8269398 |
# | 327  |  22216548.0   | 45.757785  | 4.827998  |
# | 328  |  22218349.0   | 45.756112  | 4.8263145 |
# | 329  |  22218377.0   | 45.7558598 | 4.8262119 |
# | 330  |  22218444.0   | 45.754936  | 4.8258508 |
# | 331  |  22218474.0   | 45.754619  | 4.8257354 |
# | 332  |  22218513.0   | 45.7543112 | 4.8255624 |
# | 333  |  22218540.0   | 45.7540606 |  4.82542  |
# | 334  |  22470837.0   | 45.7535446 | 4.8251377 |
# | 335  |  22470880.0   | 45.7531004 | 4.8248918 |
# | 336  |  22470962.0   | 45.7526444 | 4.8246341 |
# | 337  |  23666815.0   | 45.7521649 | 4.8264093 |
# | 338  |  23666834.0   | 45.7525067 | 4.8251574 |
# | 339  |  23666882.0   | 45.7529392 | 4.8254665 |
# | 340  |  23666905.0   | 45.7526052 | 4.8266878 |
# | 341  |  23666923.0   | 45.7530273 | 4.8269712 |
# | 342  |  23666931.0   | 45.7533653 | 4.8257658 |
# | 343  |  23666981.0   | 45.7538079 | 4.826076  |
# | 344  |  23667013.0   | 45.7540454 | 4.8262464 |
# | 345  |  23667053.0   | 45.7546751 | 4.8266945 |
# | 346  |  23667059.0   | 45.7544206 | 4.8274795 |
# | 347  |  23667112.0   | 45.7541958 | 4.8281886 |
# | 348  |  23667198.0   | 45.7537317 | 4.8278513 |
# | 349  |  23667222.0   | 45.7518918 | 4.8273309 |
# | 350  |  23667285.0   | 45.7527156 | 4.828083  |
# | 351  |  23667335.0   | 45.7534303 | 4.8286989 |
# | 352  |  23667339.0   | 45.7538994 | 4.8290851 |
# | 353  |  23668161.0   | 45.7537389 | 4.8296053 |
# | 354  |  23669146.0   | 45.7577942 | 4.8301197 |
# | 355  |  23669320.0   |  45.75804  | 4.8292958 |
# | 356  |  23669387.0   | 45.7574615 | 4.8288488 |
# | 357  |  23669474.0   | 45.7572745 | 4.8294473 |
# | 358  |  23758496.0   | 45.7588565 | 4.8307633 |
# | 359  |  23758541.0   | 45.7571061 | 4.8300485 |
# | 360  |  23842995.0   | 45.7560286 | 4.8310609 |
# | 361  |  23843288.0   |  45.75226  | 4.8297575 |
# | 362  |  23843291.0   | 45.7513727 | 4.8292421 |
# | 363  |  24009837.0   | 45.7524564 | 4.8461398 |
# | 364  |  24009841.0   | 45.7520295 | 4.8458968 |
# | 365  |  24289061.0   | 45.7550686 | 4.8115035 |
# | 366  |  24289066.0   | 45.7547005 | 4.812403  |
# | 367  |  24289146.0   | 45.7508422 | 4.8144033 |
# | 368  |  24289158.0   | 45.7519272 | 4.8166211 |
# | 369  |  24484855.0   | 45.7564034 | 4.8279906 |
# | 370  |  24484923.0   | 45.7561132 | 4.8287213 |
# | 371  |  24484925.0   | 45.7558169 | 4.8294319 |
# | 372  |  24484928.0   | 45.7554266 | 4.8281169 |
# | 373  |  24484932.0   | 45.7551257 | 4.828885  |
# | 374  |  24484937.0   | 45.7547778 | 4.8297738 |
# | 375  |  24484941.0   | 45.7555946 | 4.8300006 |
# | 376  |  24485668.0   | 45.7529724 | 4.8301539 |
# | 377  |  24485734.0   | 45.7534787 | 4.8304411 |
# | 378  |  24485740.0   | 45.752621  | 4.831429  |
# | 379  |  24485746.0   | 45.7518978 | 4.8310601 |
# | 380  |  24485749.0   | 45.7514988 | 4.8325212 |
# | 381  |  24485754.0   | 45.7521906 | 4.832998  |
# | 382  |  24485759.0   | 45.7525666 | 4.8332607 |
# | 383  |  24485763.0   | 45.7530984 | 4.8316784 |
# | 384  |  24485888.0   | 45.7536456 | 4.8327847 |
# | 385  |  24485922.0   | 45.7539111 | 4.8321048 |
# | 386  |  24485956.0   | 45.7543448 |  4.8309   |
# | 387  |  24526417.0   | 45.7468909 | 4.8273671 |
# | 388  |  24644347.0   | 45.7720831 | 4.8596588 |
# | 389  |  24644383.0   | 45.7721289 | 4.8588498 |
# | 390  |  24809643.0   | 45.7550743 | 4.8312961 |
# | 391  |  24809664.0   | 45.7557778 | 4.8316594 |
# | 392  |  24809679.0   |  45.75531  | 4.8328498 |
# | 393  |  24809692.0   | 45.7546291 | 4.8324662 |
# | 394  |  24810638.0   | 45.7538122 | 4.8344369 |
# | 395  |  25114928.0   | 45.7587231 | 4.8116823 |
# | 396  |  25115153.0   | 45.7574129 | 4.8110675 |
# | 397  |  25115178.0   | 45.7575944 | 4.8115003 |
# | 398  |  25115182.0   | 45.7570567 | 4.8125307 |
# | 399  |  25149511.0   | 45.7501063 | 4.8301328 |
# | 400  |  25149512.0   | 45.7497597 | 4.8313259 |
# | 401  |  25149513.0   | 45.7501683 | 4.8316125 |
# | 402  |  25149514.0   | 45.7505217 | 4.8303501 |
# | 403  |  25149521.0   | 45.7510094 | 4.8306061 |
# | 404  |  25149522.0   | 45.7506291 | 4.8319348 |
# | 405  |  25149523.0   | 45.7505226 | 4.8287025 |
# | 406  |  25152142.0   | 45.7470216 | 4.8564905 |
# | 407  |  25152442.0   | 45.7479258 | 4.856175  |
# | 408  |  25152444.0   | 45.7473225 | 4.858252  |
# | 409  |  25152584.0   | 45.7484915 | 4.8546812 |
# | 410  |  25152613.0   | 45.7484428 | 4.854807  |
# | 411  |  25152615.0   | 45.7478452 | 4.8514693 |
# | 412  |  25152616.0   | 45.7476723 | 4.8502842 |
# | 413  |  25152618.0   | 45.7479514 | 4.852178  |
# | 414  |  25152621.0   | 45.7474473 | 4.8514513 |
# | 415  |  25152679.0   | 45.7485895 | 4.8505603 |
# | 416  |  25152680.0   | 45.748394  | 4.8516285 |
# | 417  |  25152845.0   | 45.7465714 | 4.8501811 |
# | 418  |  25152846.0   | 45.7467403 | 4.8498074 |
# | 419  |  25152849.0   | 45.7465773 | 4.8497011 |
# | 420  |  25152928.0   | 45.7464238 | 4.8480059 |
# | 421  |  25153048.0   | 45.7479128 | 4.8478993 |
# | 422  |  25153067.0   | 45.7472299 | 4.8475653 |
# | 423  |  25153069.0   | 45.7475363 | 4.8463158 |
# | 424  |  25153070.0   | 45.7478664 | 4.8457304 |
# | 425  |  25153071.0   | 45.7483149 | 4.8449759 |
# | 426  |  25153072.0   | 45.7487749 | 4.8455529 |
# | 427  |  25153074.0   | 45.7492852 | 4.8447503 |
# | 428  |  25153075.0   | 45.7491823 | 4.8460205 |
# | 429  |  25153076.0   | 45.7480943 | 4.8469983 |
# | 430  |  25153094.0   | 45.7484125 | 4.846383  |
# | 431  |  25153100.0   | 45.7477945 | 4.8443529 |
# | 432  |  25153101.0   | 45.7470281 | 4.8456973 |
# | 433  |  25153102.0   | 45.7491625 | 4.8478678 |
# | 434  |  25153103.0   | 45.7496972 | 4.8466386 |
# | 435  |  25153108.0   | 45.7469592 | 4.8458067 |
# | 436  |  25173749.0   | 45.7498963 | 4.8549566 |
# | 437  |  25173760.0   | 45.7493127 | 4.8548497 |
# | 438  |  25173820.0   | 45.7500127 | 4.858269  |
# | 439  |  25173835.0   | 45.7504514 | 4.8569612 |
# | 440  |  25173843.0   | 45.7510888 | 4.8551894 |
# | 441  |  25174163.0   | 45.7496966 | 4.8538993 |
# | 442  |  25175743.0   | 45.7532003 | 4.8555569 |
# | 443  |  25175764.0   | 45.7533007 | 4.8563887 |
# | 444  |  25175778.0   | 45.7534307 | 4.8574652 |
# | 445  |  25175791.0   | 45.7540771 | 4.8574172 |
# | 446  |  25175794.0   | 45.7539624 | 4.8562481 |
# | 447  |  25175798.0   | 45.7538837 | 4.8554142 |
# | 448  |  25175805.0   | 45.7549946 | 4.8560371 |
# | 449  |  25175819.0   | 45.7550026 | 4.8591368 |
# | 450  |  25248947.0   | 45.7511667 | 4.8231535 |
# | 451  |  25258518.0   | 45.7560655 | 4.850468  |
# | 452  |  25258519.0   | 45.7568815 | 4.8507845 |
# | 453  |  25258521.0   | 45.7560801 | 4.8514571 |
# | 454  |  25258522.0   | 45.7574742 | 4.8512075 |
# | 455  |  25258523.0   | 45.7560766 | 4.8511988 |
# | 456  |  25258524.0   | 45.754716  | 4.8506657 |
# | 457  |  25258525.0   | 45.7545929 | 4.8517478 |
# | 458  |  25258527.0   | 45.7548504 | 4.8499631 |
# | 459  |  25258528.0   | 45.7560577 | 4.8497298 |
# | 460  |  25258529.0   | 45.7544357 | 4.8500553 |
# | 461  |  25258530.0   | 45.7543195 | 4.8488066 |
# | 462  |  25258534.0   | 45.7568487 | 4.8501933 |
# | 463  |  25258535.0   | 45.7568205 | 4.8495946 |
# | 464  |  25258539.0   | 45.7560575 | 4.8491151 |
# | 465  |  25258542.0   | 45.7560439 | 4.8484837 |
# | 466  |  25258545.0   | 45.7551823 | 4.8486404 |
# | 467  |  25258720.0   | 45.7589992 | 4.8491751 |
# | 468  |  25258721.0   | 45.7589527 | 4.8485663 |
# | 469  |  25258722.0   | 45.7589005 | 4.847954  |
# | 470  |  25258724.0   | 45.7588143 | 4.8469336 |
# | 471  |  25258725.0   | 45.7582771 | 4.8470303 |
# | 472  |  25258726.0   | 45.758329  | 4.8478365 |
# | 473  |  25258728.0   | 45.7583433 | 4.8480538 |
# | 474  |  25258729.0   | 45.7583848 | 4.8486813 |
# | 475  |  25258732.0   | 45.7584251 | 4.8492921 |
# | 476  |  25258734.0   | 45.7584696 | 4.8499663 |
# | 477  |  25258737.0   | 45.7585383 | 4.8510082 |
# | 478  |  25258741.0   | 45.7580305 | 4.8511029 |
# | 479  |  25258743.0   | 45.7579646 | 4.8500427 |
# | 480  |  25258746.0   | 45.7574004 | 4.8501236 |
# | 481  |  25258749.0   | 45.7579236 | 4.8493822 |
# | 482  |  25258750.0   | 45.7578854 | 4.8487678 |
# | 483  |  25258751.0   | 45.7578468 | 4.8481472 |
# | 484  |  25258753.0   | 45.7572951 | 4.8478147 |
# | 485  |  25258755.0   | 45.7575425 | 4.8471723 |
# | 486  |  25258757.0   | 45.7565379 | 4.8473681 |
# | 487  |  25258758.0   | 45.7566638 | 4.8478095 |
# | 488  |  25258759.0   | 45.7590581 | 4.8498929 |
# | 489  |  25303795.0   | 45.7441875 | 4.8770525 |
# | 490  |  25303796.0   | 45.7457635 | 4.8797014 |
# | 491  |  25303799.0   | 45.746539  | 4.8774607 |
# | 492  |  25303800.0   | 45.7475829 | 4.8776324 |
# | 493  |  25303801.0   | 45.7467443 | 4.8801969 |
# | 494  |  25303803.0   | 45.7476999 | 4.8817078 |
# | 495  |  25303804.0   | 45.7474719 | 4.8824343 |
# | 496  |  25303805.0   | 45.7453903 | 4.8815328 |
# | 497  |  25303806.0   | 45.7454749 | 4.8824318 |
# | 498  |  25303807.0   | 45.747287  | 4.8830361 |
# | 499  |  25303831.0   | 45.7497917 | 4.8757147 |
# | 500  |  25303832.0   |  45.74935  | 4.8767177 |
# | 501  |  25303833.0   | 45.7488925 | 4.8779019 |
# | 502  |  25303836.0   | 45.749327  | 4.8802006 |
# | 503  |  25303840.0   | 45.7522044 | 4.8746625 |
# | 504  |  25303841.0   | 45.7518474 | 4.8765423 |
# | 505  |  25305955.0   | 45.7498407 | 4.8485366 |
# | 506  |  25305960.0   | 45.7488604 | 4.8481451 |
# | 507  |  25306024.0   | 45.7517221 | 4.848997  |
# | 508  |  25306030.0   | 45.7517148 | 4.8522848 |
# | 509  |  25306034.0   | 45.7527837 | 4.8520931 |
# | 510  |  25306035.0   | 45.7535511 | 4.8519541 |
# | 511  |  25306036.0   | 45.7533894 | 4.8502407 |
# | 512  |  25306159.0   | 45.7562968 | 4.8464982 |
# | 513  |  25306160.0   | 45.7560285 | 4.8465547 |
# | 514  |  25306161.0   | 45.7550147 | 4.846768  |
# | 515  |  25306162.0   | 45.7556302 | 4.8475334 |
# | 516  |  25306163.0   | 45.7553926 | 4.8475689 |
# | 517  |  25306164.0   | 45.7535847 | 4.8479398 |
# | 518  |  25306175.0   | 45.7568031 | 4.848972  |
# | 519  |  25306176.0   | 45.7567817 | 4.8483501 |
# | 520  |  25306178.0   | 45.7574592 | 4.8462535 |
# | 521  |  25306180.0   | 45.7587374 | 4.8459845 |
# | 522  |  25306181.0   | 45.7594473 | 4.8458334 |
# | 523  |  25306182.0   | 45.7595165 | 4.8467845 |
# | 524  |  25306183.0   | 45.7595929 | 4.847833  |
# | 525  |  25306184.0   | 45.7596373 | 4.8484429 |
# | 526  |  25306185.0   | 45.7596814 | 4.8490493 |
# | 527  |  25306186.0   | 45.7597358 | 4.8497968 |
# | 528  |  25310822.0   | 45.7722585 | 4.8527775 |
# | 529  |  25310823.0   | 45.7715222 | 4.8529124 |
# | 530  |  25310824.0   | 45.7714333 | 4.8519736 |
# | 531  |  25310825.0   | 45.7721712 | 4.8518307 |
# | 532  |  25310826.0   | 45.7720761 | 4.8508216 |
# | 533  |  25310829.0   | 45.7719877 | 4.8499223 |
# | 534  |  25310830.0   | 45.7738339 | 4.8487745 |
# | 535  |  25310831.0   | 45.7730012 | 4.8489341 |
# | 536  |  25310832.0   | 45.7719167 | 4.8491421 |
# | 537  |  25310854.0   | 45.7704524 | 4.8540342 |
# | 538  |  25310855.0   | 45.7711472 | 4.8539175 |
# | 539  |  25310856.0   | 45.7709755 | 4.8520702 |
# | 540  |  25310857.0   | 45.770267  | 4.8522008 |
# | 541  |  25310858.0   | 45.7705398 | 4.8550127 |
# | 542  |  25310859.0   | 45.7706686 | 4.8562801 |
# | 543  |  25310860.0   | 45.7712383 | 4.8548974 |
# | 544  |  25310861.0   | 45.7713062 | 4.855628  |
# | 545  |  25310862.0   | 45.7697443 | 4.8551708 |
# | 546  |  25310863.0   | 45.7698404 | 4.8561454 |
# | 547  |  25310864.0   | 45.7690833 | 4.8562916 |
# | 548  |  25310866.0   | 45.7684164 | 4.8569852 |
# | 549  |  25310867.0   | 45.7691433 | 4.8570448 |
# | 550  |  25310868.0   | 45.7699336 | 4.8570651 |
# | 551  |  25310869.0   | 45.7689762 | 4.8552997 |
# | 552  |  25310870.0   | 45.7682667 | 4.8554298 |
# | 553  |  25310871.0   | 45.7677968 | 4.8555169 |
# | 554  |  25310872.0   | 45.7678951 | 4.8565234 |
# | 555  |  25310873.0   | 45.7679292 | 4.8569681 |
# | 556  |  25310874.0   | 45.7670571 | 4.8556519 |
# | 557  |  25310875.0   | 45.7669613 | 4.8546524 |
# | 558  |  25310876.0   | 45.7677082 | 4.8545142 |
# | 559  |  25310877.0   | 45.768171  | 4.8544384 |
# | 560  |  25310878.0   | 45.7688804 | 4.8542975 |
# | 561  |  25310879.0   | 45.7696477 | 4.8541634 |
# | 562  |  25310880.0   |  45.76948  | 4.8523652 |
# | 563  |  25310881.0   | 45.7687094 | 4.8525005 |
# | 564  |  25310882.0   | 45.7680104 | 4.8526428 |
# | 565  |  25310885.0   | 45.7675416 | 4.852739  |
# | 566  |  25310886.0   | 45.7675883 | 4.8533062 |
# | 567  |  25310887.0   | 45.7673547 | 4.8507607 |
# | 568  |  25310888.0   | 45.7678339 | 4.8506687 |
# | 569  |  25310889.0   | 45.7685281 | 4.8505404 |
# | 570  |  25310890.0   | 45.7652926 | 4.854939  |
# | 571  |  25310891.0   | 45.7659384 | 4.854836  |
# | 572  |  25310893.0   | 45.7653806 | 4.8559613 |
# | 573  |  25310894.0   | 45.764542  | 4.8561134 |
# | 574  |  25310895.0   | 45.764588  | 4.8571769 |
# | 575  |  25310896.0   | 45.764495  | 4.8551013 |
# | 576  |  25310897.0   | 45.7644447 | 4.8537493 |
# | 577  |  25310898.0   | 45.7644271 | 4.8533204 |
# | 578  |  25310899.0   | 45.7651211 | 4.8531976 |
# | 579  |  25310900.0   | 45.7657769 | 4.853081  |
# | 580  |  25310901.0   | 45.7667998 | 4.8528795 |
# | 581  |  25310902.0   | 45.7667068 | 4.8518885 |
# | 582  |  25310903.0   | 45.7656832 | 4.8520784 |
# | 583  |  25310904.0   | 45.7650294 | 4.8521896 |
# | 584  |  25310905.0   | 45.7643788 | 4.852293  |
# | 585  |  25310907.0   | 45.7636239 | 4.8562686 |
# | 586  |  25310908.0   | 45.7636312 | 4.8573731 |
# | 587  |  25310909.0   | 45.7654782 | 4.8570684 |
# | 588  |  25310910.0   | 45.7661294 | 4.8569474 |
# | 589  |  25310911.0   | 45.7671387 | 4.8566588 |
# | 590  |  25310913.0   | 45.7662295 | 4.8581363 |
# | 591  |  25310931.0   | 45.7615264 | 4.8442608 |
# | 592  |  25310932.0   | 45.7608281 | 4.8444022 |
# | 593  |  25310933.0   | 45.7616173 | 4.8453748 |
# | 594  |  25312121.0   | 45.7464466 | 4.8284683 |
# | 595  |  25312123.0   | 45.744341  | 4.8267483 |
# | 596  |  25312126.0   | 45.7462537 | 4.8254021 |
# | 597  |  25312127.0   | 45.7452584 | 4.8245449 |
# | 598  |  25312128.0   | 45.7448135 | 4.8255853 |
# | 599  |  25312129.0   | 45.7458158 | 4.8264517 |
# | 600  |  25312133.0   | 45.7432255 | 4.8228144 |
# | 601  |  25312134.0   | 45.7442288 | 4.8236615 |
# | 602  |  25312135.0   | 45.7437775 | 4.8247215 |
# | 603  |  25312136.0   | 45.7427901 | 4.8238738 |
# | 604  |  25312137.0   | 45.7423086 | 4.8250174 |
# | 605  |  25312138.0   | 45.7433104 | 4.8258661 |
# | 606  |  25312144.0   | 45.7416961 | 4.822923  |
# | 607  |  25312373.0   | 45.7566541 | 4.7824857 |
# | 608  |  25312477.0   | 45.7559192 | 4.7880508 |
# | 609  |  25316171.0   | 45.773416  | 4.8441416 |
# | 610  |  25316172.0   | 45.7735051 | 4.8451743 |
# | 611  |  25316173.0   | 45.7736197 | 4.8464219 |
# | 612  |  25316174.0   | 45.7736996 | 4.8472589 |
# | 613  |  25316175.0   | 45.7737828 | 4.8481207 |
# | 614  |  25316176.0   | 45.7729409 | 4.8482851 |
# | 615  |  25316177.0   | 45.7728615 | 4.8474271 |
# | 616  |  25316178.0   | 45.7725712 | 4.8443017 |
# | 617  |  25316179.0   | 45.772668  | 4.8453332 |
# | 618  |  25316180.0   | 45.7724599 | 4.843095  |
# | 619  |  25316181.0   | 45.773298  | 4.8429229 |
# | 620  |  25316182.0   | 45.774202  | 4.8427333 |
# | 621  |  25316184.0   | 45.7744052 | 4.8450095 |
# | 622  |  25316185.0   | 45.7745208 | 4.846251  |
# | 623  |  25316186.0   | 45.7746092 | 4.8471059 |
# | 624  |  25316187.0   | 45.7715884 | 4.8455211 |
# | 625  |  25316188.0   | 45.7719356 | 4.8454767 |
# | 626  |  25316189.0   | 45.7718221 | 4.8444341 |
# | 627  |  25316190.0   | 45.771709  | 4.8432508 |
# | 628  |  25316191.0   | 45.7713958 | 4.8433151 |
# | 629  |  25316192.0   | 45.7713247 | 4.842385  |
# | 630  |  25316193.0   | 45.772375  | 4.8421804 |
# | 631  |  25316194.0   | 45.7728622 | 4.8420855 |
# | 632  |  25316195.0   | 45.7729533 | 4.8429926 |
# | 633  |  25316196.0   | 45.7732198 | 4.842016  |
# | 634  |  25316197.0   | 45.7717035 | 4.8467852 |
# | 635  |  25316199.0   |  45.77178  | 4.8476338 |
# | 636  |  25316247.0   | 45.7708491 | 4.8456818 |
# | 637  |  25316249.0   | 45.7703738 | 4.8457669 |
# | 638  |  25316250.0   | 45.7696772 | 4.8459047 |
# | 639  |  25316251.0   | 45.7704937 | 4.847008  |
# | 640  |  25316252.0   | 45.7697968 | 4.8471295 |
# | 641  |  25316254.0   | 45.769585  | 4.8448639 |
# | 642  |  25316255.0   | 45.7702749 | 4.8447334 |
# | 643  |  25316256.0   | 45.7706377 | 4.8434731 |
# | 644  |  25316257.0   | 45.7705526 | 4.8425353 |
# | 645  |  25316258.0   | 45.7712345 | 4.8415467 |
# | 646  |  25316259.0   | 45.7704742 | 4.8416998 |
# | 647  |  25316260.0   | 45.7694792 | 4.8437136 |
# | 648  |  25316261.0   | 45.7711183 | 4.8486238 |
# | 649  |  25316262.0   | 45.7706519 | 4.848709  |
# | 650  |  25316263.0   | 45.7699537 | 4.8488399 |
# | 651  |  25316365.0   | 45.7683896 | 4.849131  |
# | 652  |  25316384.0   | 45.7677086 | 4.8492684 |
# | 653  |  25316395.0   | 45.7668588 | 4.8453766 |
# | 654  |  25316399.0   | 45.7669467 | 4.8464148 |
# | 655  |  25316410.0   | 45.7670638 | 4.8476461 |
# | 656  |  25316417.0   | 45.7672273 | 4.8493646 |
# | 657  |  25316435.0   | 45.7681226 | 4.8461959 |
# | 658  |  25316436.0   | 45.7674446 | 4.8463153 |
# | 659  |  25319177.0   | 45.7641782 | 4.853377  |
# | 660  |  25319178.0   | 45.7636086 | 4.8534946 |
# | 661  |  25319181.0   | 45.7636033 | 4.8526175 |
# | 662  |  25319182.0   | 45.7635851 | 4.8483007 |
# | 663  |  25319183.0   | 45.7635738 | 4.847063  |
# | 664  |  25319190.0   | 45.763563  | 4.8449595 |
# | 665  |  25319193.0   | 45.7644544 | 4.8458466 |
# | 666  |  25319194.0   | 45.7650833 | 4.8457397 |
# | 667  |  25319195.0   | 45.7660179 | 4.8444431 |
# | 668  |  25319196.0   | 45.7643676 | 4.8447925 |
# | 669  |  25319201.0   | 45.7666658 | 4.8432864 |
# | 670  |  25319202.0   | 45.765918  | 4.8434262 |
# | 671  |  25319203.0   | 45.7665868 | 4.8424305 |
# | 672  |  25319204.0   | 45.7658413 | 4.8425784 |
# | 673  |  25319205.0   | 45.7648193 | 4.8427653 |
# | 674  |  25319206.0   | 45.7642033 | 4.8428922 |
# | 675  |  25319207.0   | 45.7635883 | 4.8430023 |
# | 676  |  25319208.0   | 45.7635633 | 4.8438759 |
# | 677  |  25319211.0   | 45.7642741 | 4.8437434 |
# | 678  |  25319212.0   | 45.7648868 | 4.8436216 |
# | 679  |  25319255.0   | 45.7622443 | 4.8462682 |
# | 680  |  25319257.0   | 45.7621645 | 4.845259  |
# | 681  |  25319258.0   | 45.7616892 | 4.8463678 |
# | 682  |  25319259.0   | 45.7609685 | 4.8465054 |
# | 683  |  25319260.0   | 45.7625074 | 4.8432032 |
# | 684  |  25319261.0   | 45.7614648 | 4.8433969 |
# | 685  |  25319302.0   | 45.7635659 | 4.8460249 |
# | 686  |  25321302.0   | 45.7499524 | 4.8637674 |
# | 687  |  25321304.0   | 45.7484299 | 4.8656289 |
# | 688  |  25321309.0   | 45.7459824 | 4.8735584 |
# | 689  |  25321323.0   | 45.7458433 | 4.8749699 |
# | 690  |  25321327.0   | 45.7470582 | 4.8751976 |
# | 691  |  25321330.0   | 45.7473038 | 4.8739515 |
# | 692  |  25321354.0   | 45.7468606 | 4.8719087 |
# | 693  |  25321357.0   | 45.7472549 | 4.8703412 |
# | 694  |  25321359.0   | 45.7477985 | 4.8724475 |
# | 695  |  25321407.0   | 45.7485122 | 4.8728576 |
# | 696  |  25321408.0   | 45.7488931 | 4.8730844 |
# | 697  |  25321422.0   | 45.7490234 | 4.873164  |
# | 698  |  25321433.0   | 45.7496968 | 4.8734548 |
# | 699  |  25321447.0   | 45.7506695 | 4.8739294 |
# | 700  |  25321456.0   | 45.7492136 | 4.875591  |
# | 701  |  25321469.0   | 45.7484026 | 4.8754386 |
# | 702  |  25321687.0   | 45.7515419 | 4.8743803 |
# | 703  |  25321689.0   | 45.7511372 | 4.8762449 |
# | 704  |  25327117.0   |  45.77324  | 4.8516323 |
# | 705  |  25327118.0   | 45.7728043 | 4.8527146 |
# | 706  |  25327119.0   | 45.7723736 | 4.8538338 |
# | 707  |  25327120.0   | 45.7719513 | 4.8548067 |
# | 708  |  25327121.0   | 45.7717342 | 4.8551517 |
# | 709  |  25327122.0   | 45.7716977 | 4.8548135 |
# | 710  |  25327123.0   | 45.771603  | 4.8538233 |
# | 711  |  25327124.0   | 45.7713417 | 4.8509527 |
# | 712  |  25327125.0   | 45.7712573 | 4.8500493 |
# | 713  |  25327127.0   | 45.7692966 | 4.8504003 |
# | 714  |  25327128.0   | 45.7707949 | 4.8501275 |
# | 715  |  25327129.0   | 45.7700881 | 4.8502571 |
# | 716  |  25327130.0   | 45.7688967 | 4.8460644 |
# | 717  |  25327131.0   | 45.7663299 | 4.8477838 |
# | 718  |  25327132.0   | 45.7662075 | 4.8465526 |
# | 719  |  25327133.0   | 45.7657079 | 4.8466469 |
# | 720  |  25327134.0   | 45.7651726 | 4.8467558 |
# | 721  |  25327135.0   | 45.7645524 | 4.8468718 |
# | 722  |  25327136.0   | 45.7639786 | 4.8459303 |
# | 723  |  25327137.0   | 45.7640923 | 4.8469618 |
# | 724  |  25327138.0   | 45.7642023 | 4.8481896 |
# | 725  |  25327139.0   | 45.7646541 | 4.8481094 |
# | 726  |  25327140.0   | 45.7649399 | 4.8512063 |
# | 727  |  25327143.0   | 45.7652949 | 4.8479824 |
# | 728  |  25327144.0   | 45.766477  | 4.8494928 |
# | 729  |  25327145.0   | 45.7654436 | 4.849695  |
# | 730  |  25327146.0   | 45.7655826 | 4.8510875 |
# | 731  |  25327147.0   | 45.7666148 | 4.8508973 |
# | 732  |  25327148.0   | 45.7658193 | 4.8478826 |
# | 733  |  25327152.0   | 45.7674458 | 4.8517521 |
# | 734  |  25327153.0   | 45.7668466 | 4.8534469 |
# | 735  |  25334263.0   | 45.7453527 | 4.8687019 |
# | 736  |  25334276.0   | 45.7446692 | 4.8679982 |
# | 737  |  25334281.0   | 45.7455165 | 4.8680559 |
# | 738  |  25334299.0   | 45.7458729 | 4.8666075 |
# | 739  |  25334340.0   | 45.7462556 | 4.8667777 |
# | 740  |  25334442.0   | 45.7496615 | 4.8651052 |
# | 741  |  25335974.0   | 45.7488564 | 4.8683229 |
# | 742  |  25335981.0   | 45.7505187 | 4.8685318 |
# | 743  |  25336175.0   | 45.7530077 | 4.8636362 |
# | 744  |  25336178.0   | 45.7525457 | 4.8658533 |
# | 745  |  25336179.0   | 45.7541319 | 4.8631939 |
# | 746  |  25336189.0   | 45.752632  | 4.8687186 |
# | 747  |  25336247.0   | 45.7503989 | 4.8738088 |
# | 748  |  25336254.0   | 45.7519541 | 4.8713354 |
# | 749  |  25337448.0   | 45.7500538 | 4.8470851 |
# | 750  |  25337450.0   | 45.749687  | 4.8479283 |
# | 751  |  25337452.0   | 45.7509031 | 4.8466866 |
# | 752  |  25337454.0   | 45.7508128 | 4.8487194 |
# | 753  |  25337455.0   | 45.7505499 | 4.8462641 |
# | 754  |  25337456.0   | 45.750108  | 4.8457271 |
# | 755  |  25337457.0   | 45.7515257 | 4.8474463 |
# | 756  |  25337458.0   | 45.751618  | 4.8444624 |
# | 757  |  25337459.0   | 45.7520347 | 4.8449632 |
# | 758  |  25337460.0   | 45.7517501 | 4.8454389 |
# | 759  |  25337461.0   | 45.7516023 | 4.8456537 |
# | 760  |  25337462.0   | 45.7513506 | 4.8449091 |
# | 761  |  25337463.0   | 45.7511007 | 4.8453565 |
# | 762  |  25337464.0   | 45.7523984 | 4.8443424 |
# | 763  |  25337465.0   | 45.7533387 | 4.842693  |
# | 764  |  25337467.0   | 45.7530282 | 4.8450783 |
# | 765  |  25337468.0   | 45.7525081 | 4.8429329 |
# | 766  |  25337469.0   | 45.7529029 | 4.8422445 |
# | 767  |  25450957.0   | 45.7508135 | 4.8424315 |
# | 768  |  25450959.0   | 45.7515228 | 4.8432812 |
# | 769  |  25450960.0   | 45.7519891 | 4.8438257 |
# | 770  |  25450962.0   | 45.7508182 | 4.844156  |
# | 771  |  25450963.0   | 45.750446  | 4.8430083 |
# | 772  |  25450964.0   | 45.7502172 | 4.8433417 |
# | 773  |  25450965.0   | 45.7519157 | 4.8423987 |
# | 774  |  25450966.0   | 45.7522033 | 4.8415973 |
# | 775  |  25450967.0   | 45.7512354 | 4.8417883 |
# | 776  |  25451370.0   | 45.7503445 | 4.8665991 |
# | 777  |  25451454.0   | 45.7452961 | 4.8719844 |
# | 778  |  25451455.0   | 45.7438665 | 4.8712522 |
# | 779  |  25451862.0   | 45.7466133 | 4.8373995 |
# | 780  |  25451863.0   | 45.7473183 | 4.8382122 |
# | 781  |  25451865.0   | 45.7479987 | 4.8390153 |
# | 782  |  25451866.0   | 45.7477595 | 4.839656  |
# | 783  |  25451868.0   | 45.7486338 | 4.8397902 |
# | 784  |  25451869.0   | 45.7481593 | 4.8385669 |
# | 785  |  25451871.0   | 45.7484158 | 4.8378947 |
# | 786  |  25451872.0   | 45.7476449 | 4.8373622 |
# | 787  |  25451935.0   | 45.7474015 | 4.8380117 |
# | 788  |  25451937.0   | 45.7502401 | 4.8417403 |
# | 789  |  25451944.0   | 45.7497152 | 4.8426231 |
# | 790  |  25451960.0   | 45.7492228 | 4.8419654 |
# | 791  |  25451970.0   | 45.7488713 | 4.8414856 |
# | 792  |  25451982.0   | 45.7484052 | 4.8403475 |
# | 793  |  25451998.0   | 45.7491786 | 4.8384304 |
# | 794  |  25451999.0   | 45.7488998 | 4.8391142 |
# | 795  |  25452392.0   | 45.7544296 | 4.8455045 |
# | 796  |  25452393.0   | 45.7541217 | 4.8463708 |
# | 797  |  25452874.0   | 45.7298451 | 4.8348529 |
# | 798  |  25452878.0   | 45.7299582 | 4.8367081 |
# | 799  |  25452882.0   | 45.7287476 | 4.8363639 |
# | 800  |  25452884.0   | 45.7282643 | 4.8342161 |
# | 801  |  25452885.0   | 45.7282623 | 4.834755  |
# | 802  |  25452887.0   | 45.7312185 | 4.8385143 |
# | 803  |  25452888.0   | 45.7313116 | 4.8354304 |
# | 804  |  25454179.0   | 45.7513223 | 4.8258608 |
# | 805  |  25468003.0   | 45.7663261 | 4.8634663 |
# | 806  |  25468004.0   | 45.7663412 | 4.8648108 |
# | 807  |  25468005.0   | 45.7663518 | 4.8658273 |
# | 808  |  25468009.0   | 45.7666984 | 4.8634134 |
# | 809  |  25468010.0   | 45.7673997 | 4.8647924 |
# | 810  |  25468011.0   | 45.7671973 | 4.864795  |
# | 811  |  25468012.0   | 45.7672982 | 4.8633222 |
# | 812  |  25468014.0   | 45.7674626 | 4.8658106 |
# | 813  |  25468017.0   | 45.7682629 | 4.8647788 |
# | 814  |  25468019.0   | 45.7681584 | 4.863209  |
# | 815  |  25468020.0   | 45.7681329 | 4.8625069 |
# | 816  |  25468021.0   | 45.7672877 | 4.8625939 |
# | 817  |  25468022.0   | 45.7663111 | 4.8618258 |
# | 818  |  25468023.0   | 45.7672665 | 4.8617977 |
# | 819  |  25468030.0   | 45.7663682 | 4.8671818 |
# | 820  |  25468037.0   | 45.7643351 | 4.8628418 |
# | 821  |  25468038.0   | 45.7643416 | 4.863703  |
# | 822  |  25468040.0   | 45.762931  | 4.8638044 |
# | 823  |  25468041.0   | 45.7620285 | 4.8638413 |
# | 824  |  25468043.0   | 45.7636867 | 4.8658869 |
# | 825  |  25468044.0   | 45.7636908 | 4.8670403 |
# | 826  |  25468045.0   | 45.7636922 | 4.8679216 |
# | 827  |  25468066.0   | 45.7629391 | 4.8668802 |
# | 828  |  25468067.0   | 45.7620151 | 4.8646841 |
# | 829  |  25468068.0   | 45.7629245 | 4.8647157 |
# | 830  |  25468069.0   | 45.7629219 | 4.8629053 |
# | 831  |  25468070.0   | 45.7620403 | 4.8629371 |
# | 832  |  25468073.0   | 45.7629083 | 4.8619312 |
# | 833  |  25468075.0   | 45.7629037 | 4.8618264 |
# | 834  |  25468076.0   | 45.7651564 | 4.8627558 |
# | 835  |  25468085.0   | 45.7391769 | 4.8600534 |
# | 836  |  25468090.0   | 45.739199  | 4.8597685 |
# | 837  |  25468214.0   | 45.7367157 | 4.8423532 |
# | 838  |  25468215.0   | 45.7367865 | 4.8397206 |
# | 839  |  25468216.0   | 45.7375004 | 4.8398019 |
# | 840  |  25468217.0   | 45.7382008 | 4.8399765 |
# | 841  |  25468218.0   | 45.7396499 | 4.8404089 |
# | 842  |  25468219.0   | 45.7399369 | 4.840475  |
# | 843  |  25468226.0   | 45.7387854 | 4.838042  |
# | 844  |  25468227.0   | 45.7400708 | 4.8388213 |
# | 845  |  25468228.0   | 45.7381768 | 4.8376884 |
# | 846  |  25468301.0   | 45.7265434 | 4.8307593 |
# | 847  |  25468304.0   | 45.7264645 | 4.8269056 |
# | 848  |  25468305.0   | 45.7261609 | 4.8376167 |
# | 849  |  25470101.0   | 45.7560227 | 4.8185572 |
# | 850  |  25470290.0   | 45.7599613 | 4.8225328 |
# | 851  |  25470914.0   | 45.7355108 | 4.8566321 |
# | 852  |  25470916.0   | 45.738472  | 4.8591914 |
# | 853  |  25470917.0   | 45.7380236 | 4.8531461 |
# | 854  |  25471028.0   | 45.7362805 | 4.8556612 |
# | 855  |  25471053.0   | 45.7339863 | 4.8578956 |
# | 856  |  25471072.0   | 45.7355311 | 4.8595891 |
# | 857  |  25471074.0   | 45.7340291 | 4.8627874 |
# | 858  |  25471717.0   | 45.7344248 | 4.8661181 |
# | 859  |  25471719.0   | 45.7349426 | 4.8666791 |
# | 860  |  25471728.0   | 45.733377  | 4.8645985 |
# | 861  |  25471730.0   | 45.7333029 | 4.8644167 |
# | 862  |  25471741.0   | 45.7357454 | 4.867549  |
# | 863  |  25471743.0   | 45.7343693 | 4.8676876 |
# | 864  |  25471761.0   | 45.7371758 | 4.8651743 |
# | 865  |  25478600.0   | 45.7693565 | 4.8341053 |
# | 866  |  25478602.0   | 45.7695377 | 4.8350316 |
# | 867  |  25495293.0   | 45.7457757 | 4.8479369 |
# | 868  |  25495294.0   | 45.7457694 | 4.8508079 |
# | 869  |  25495295.0   | 45.7448049 | 4.8494624 |
# | 870  |  25495298.0   | 45.7428839 | 4.8505113 |
# | 871  |  25495299.0   | 45.7438637 | 4.8519877 |
# | 872  |  25495334.0   | 45.7753895 | 4.8460759 |
# | 873  |  25495335.0   | 45.7754373 | 4.8469097 |
# | 874  |  25495336.0   | 45.7746862 | 4.8479265 |
# | 875  |  25495338.0   | 45.774882  | 4.8480699 |
# | 876  |  25495339.0   | 45.7752799 | 4.8448459 |
# | 877  |  25495340.0   | 45.7764551 | 4.8446885 |
# | 878  |  25495344.0   | 45.7739524 | 4.8500758 |
# | 879  |  25495345.0   | 45.773874  | 4.8491897 |
# | 880  |  25495346.0   | 45.7742548 | 4.8494229 |
# | 881  |  25495347.0   | 45.7746221 | 4.8486279 |
# | 882  |  25498533.0   | 45.7726189 | 4.838448  |
# | 883  |  25498538.0   | 45.7724576 | 4.8421643 |
# | 884  |  25498539.0   | 45.7725377 | 4.8430772 |
# | 885  |  25498540.0   | 45.7726402 | 4.8442919 |
# | 886  |  25498566.0   | 45.7727356 | 4.8453197 |
# | 887  |  25498567.0   | 45.7728659 | 4.8465663 |
# | 888  |  25498568.0   | 45.7729446 | 4.8474107 |
# | 889  |  25498569.0   | 45.7730246 | 4.8482714 |
# | 890  |  25498570.0   | 45.7730845 | 4.8489183 |
# | 891  |  25498571.0   | 45.7731625 | 4.8497936 |
# | 892  |  25498572.0   | 45.7733158 | 4.8514514 |
# | 893  |  25499133.0   | 45.7462011 | 4.8459813 |
# | 894  |  25499134.0   | 45.7465724 | 4.8464705 |
# | 895  |  25499136.0   | 45.7455774 | 4.848354  |
# | 896  |  25499140.0   | 45.7453645 | 4.8481102 |
# | 897  |  25499141.0   | 45.7454621 | 4.8478794 |
# | 898  |  25499149.0   | 45.7465603 | 4.8450815 |
# | 899  |  25499150.0   | 45.7467909 | 4.8444938 |
# | 900  |  25499151.0   | 45.7462164 | 4.8437522 |
# | 901  |  25499152.0   | 45.7455371 | 4.8433851 |
# | 902  |  25499153.0   | 45.7454347 | 4.8437168 |
# | 903  |  25499154.0   | 45.7459827 | 4.8443815 |
# | 904  |  25499155.0   | 45.7456471 | 4.8452768 |
# | 905  |  25499156.0   | 45.7451332 | 4.8446563 |
# | 906  |  25499159.0   | 45.7451452 | 4.8466265 |
# | 907  |  25499161.0   | 45.7448531 | 4.8429189 |
# | 908  |  25499208.0   | 45.7482304 | 4.8408198 |
# | 909  |  25499210.0   | 45.7478529 | 4.8417959 |
# | 910  |  25499212.0   | 45.7480298 | 4.8419785 |
# | 911  |  25499215.0   | 45.747749  | 4.8420508 |
# | 912  |  25499216.0   | 45.7473265 | 4.8431293 |
# | 913  |  25499217.0   | 45.7471607 | 4.8435545 |
# | 914  |  25499218.0   | 45.7472355 | 4.8410507 |
# | 915  |  25499219.0   | 45.7465489 | 4.8402531 |
# | 916  |  25499220.0   | 45.746837  | 4.8420941 |
# | 917  |  25525377.0   | 45.7360879 | 4.8633634 |
# | 918  |  25525378.0   | 45.735813  | 4.8641259 |
# | 919  |  25547435.0   | 45.7350205 | 4.855616  |
# | 920  |  25547436.0   | 45.7340562 | 4.8533693 |
# | 921  |  25547440.0   | 45.7366226 | 4.8608342 |
# | 922  |  25547441.0   | 45.7354015 | 4.853211  |
# | 923  |  25549075.0   | 45.7386129 | 4.852114  |
# | 924  |  25549076.0   | 45.741094  | 4.8512717 |
# | 925  |  25549077.0   | 45.7372917 | 4.8525611 |
# | 926  |  25610709.0   | 45.7421177 | 4.8937692 |
# | 927  |  25610743.0   | 45.7448579 | 4.8953963 |
# | 928  |  25610774.0   | 45.7440325 | 4.8934343 |
# | 929  |  25611003.0   | 45.7438315 | 4.8940019 |
# | 930  |  25611037.0   | 45.7429512 | 4.8941404 |
# | 931  |  25611040.0   | 45.7432688 | 4.8943072 |
# | 932  |  25611043.0   | 45.743445  | 4.8944738 |
# | 933  |  25611153.0   | 45.7474602 | 4.896602  |
# | 934  |  25611156.0   | 45.7495795 | 4.897084  |
# | 935  |  25611158.0   | 45.7503583 | 4.8972756 |
# | 936  |  25611272.0   | 45.7534554 | 4.8967211 |
# | 937  |  25611274.0   | 45.7537425 | 4.8952903 |
# | 938  |  25611365.0   | 45.7540182 | 4.8939251 |
# | 939  |  25611366.0   | 45.7540545 | 4.8935742 |
# | 940  |  25611375.0   | 45.7541705 | 4.8895837 |
# | 4120 | 11432105604.0 | 45.7453844 | 4.8895208 |
# | 4121 | 11432105605.0 | 45.7452721 | 4.8894352 |
# | 4122 | 11470215275.0 | 45.7267083 | 4.8857184 |
# | 4123 | 11509487125.0 | 45.749167  | 4.8449397 |
# | 4124 | 11584541404.0 | 45.8042553 | 4.834451  |
# | 4125 | 11591631528.0 | 45.7466992 | 4.8499801 |
# | 4126 | 11591631532.0 | 45.7465239 | 4.8498121 |
# | 4127 | 11690126531.0 | 45.7652007 | 4.8572897 |
# | 4128 | 11806720973.0 | 45.7476005 | 4.8775811 |
# | 4129 | 11827157240.0 | 45.7718167 | 4.8588297 |
# | 4130 | 11880778545.0 |  45.74859  | 4.7931236 |
# | 4131 | 11898137498.0 | 45.7503771 | 4.781328  |
# | 4132 | 11898137499.0 | 45.7501102 | 4.7811304 |
# | 4133 | 11908115400.0 | 45.7521066 | 4.7818012 |
# | 4134 | 11917574941.0 | 45.7416668 | 4.8492891 |
# | 4135 | 11918158672.0 | 45.7520462 | 4.7935806 |
# | 4136 | 11956024523.0 | 45.7531027 | 4.8547483 |
# | 4137 | 11959723501.0 | 45.7505288 | 4.7995814 |
# | 4138 | 11959723522.0 | 45.7496281 | 4.7957255 |
# | 4139 | 11966306052.0 | 45.7627355 | 4.807913  |
# | 4140 | 11978440262.0 | 45.7506316 | 4.8090817 |
# | 4141 | 12004355989.0 | 45.7456269 | 4.7817025 |
# | 4142 | 12035934861.0 | 45.7759097 | 4.8360071 |
# | 4143 | 12037042658.0 | 45.7464813 | 4.7883425 |
# | 4144 | 12037042661.0 | 45.7468805 | 4.7892411 |
# | 4145 | 12037042664.0 | 45.747523  | 4.7907538 |
# | 4146 | 12046689741.0 | 45.7601468 | 4.8056869 |
# | 4147 | 12046689760.0 | 45.760935  | 4.8042914 |
# | 4148 | 12046689761.0 | 45.760929  | 4.804297  |
# | 4149 | 12056816800.0 | 45.7499895 | 4.8819758 |
# | 4150 | 12112670043.0 | 45.7545442 | 4.8666067 |
# | 4151 | 12112670045.0 | 45.7569608 | 4.862626  |
# | 4152 | 12112670047.0 | 45.7560712 | 4.8640815 |
# | 4153 | 12140914736.0 | 45.7744905 | 4.826946  |
# | 4154 | 12148021235.0 | 45.7447923 | 4.8582891 |
# | 4155 | 12192585637.0 | 45.7483505 | 4.8546783 |
# | 4156 | 12192585644.0 | 45.7472255 | 4.8589264 |
# | 4157 | 12192585653.0 | 45.7452845 | 4.8584171 |
# | 4158 | 12196706426.0 | 45.765909  | 4.8154285 |
# | 4159 | 12196885700.0 | 45.7647043 | 4.8161395 |
# | 4160 | 12253467275.0 | 45.7558206 | 4.8102149 |
# | 4161 | 12254593746.0 | 45.7555372 | 4.8116763 |
# | 4162 | 12254593748.0 | 45.7554664 | 4.8116529 |
# | 4163 | 12296232780.0 | 45.7412355 | 4.8855699 |
# | 4164 | 12385083532.0 | 45.7351885 | 4.818912  |
# | 4165 | 12439930938.0 | 45.7728837 | 4.8054277 |
# | 4166 | 12439930983.0 | 45.7730272 | 4.8054218 |
# | 4167 | 12439930987.0 | 45.7728176 | 4.8054306 |
# | 4168 | 12505754910.0 | 45.7532055 | 4.8490282 |
# | 4169 | 12506959804.0 | 45.7553061 | 4.8429923 |
# | 4170 | 12568521907.0 | 45.7718843 | 4.8567205 |
# | 4171 | 12573727151.0 | 45.7330502 | 4.8402285 |
# | 4172 | 12573727155.0 | 45.7326483 | 4.8391597 |
# | 4173 | 12587706741.0 | 45.7515963 | 4.8975875 |
# | 4174 | 12588401713.0 | 45.7755322 | 4.7948449 |
# | 4175 | 12616427837.0 | 45.7720223 | 4.8180606 |
# +------+---------------+------------+-----------+

# %% [markdown]
# ## Automating the comparison process for every node

# %%
import pandas as pd
import random

def automate_comparison_process(csv_file_path, output_format, num_pairs):
    df = pd.read_csv(csv_file_path)


    if len(df) < 2:
        raise ValueError("The CSV file must contain at least two nodes.")

    simulation_results = []

    for _ in range(num_pairs):
        sample = df.sample(n=2)
        origin_row = sample.iloc[0]
        destination_row = sample.iloc[1]


        origin_str = f"{origin_row['latitude']},{origin_row['longitude']}"
        destination_str = f"{destination_row['latitude']},{destination_row['longitude']}"


        result = compare_routes(origin_str, destination_str, vehicle_params)


        if result is not None:
            simulation_results.append(result)


    save_comparison_results(simulation_results, output_format)

def save_comparison_results(results, output_format):
    if output_format == "csv":
        with open('route_comparison_results.csv', 'w', newline='') as csvfile:
            fieldnames = results[0].keys() if results else []
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writeheader()
            writer.writerows(results)
    elif output_format == "json":
        with open('route_comparison_results.json', 'w') as jsonfile:
            json.dump(results, jsonfile, indent=4)
    else:
        print(f"Unsupported output format: {output_format}")

# %%
automate_comparison_process('/content/node_coordinates.csv','csv',200)
# Out:
# Comparing routes from Origin: 45.7487628,4.8292093 to Destination: 45.7514354,4.8154953
# Comparing routes from Origin: 45.7536622,4.8593929 to Destination: 45.7360216,4.8696307
# Comparing routes from Origin: 45.7677968,4.8555169 to Destination: 45.7364052,4.8396842
# Comparing routes from Origin: 45.77952,4.8183911 to Destination: 45.783259,4.8076905
# Comparing routes from Origin: 45.7359173,4.8523024 to Destination: 45.7288286,4.8228727
# Comparing routes from Origin: 45.7535889,4.8715435 to Destination: 45.7520389,4.8554586
# Comparing routes from Origin: 45.7451203,4.8420877 to Destination: 45.7340291,4.8627874
# Comparing routes from Origin: 45.7725351,4.838088 to Destination: 45.7474128,4.8292752
# Comparing routes from Origin: 45.7508135,4.8424315 to Destination: 45.807868,4.837384
# Comparing routes from Origin: 45.7952471,4.8250787 to Destination: 45.7490234,4.873164
# Comparing routes from Origin: 45.7691709,4.8296067 to Destination: 45.7377981,4.8152033
# Comparing routes from Origin: 45.7895189,4.8130327 to Destination: 45.7466916,4.8849003
# Comparing routes from Origin: 45.7537613,4.8384968 to Destination: 45.7561443,4.8557983
# Comparing routes from Origin: 45.7285944,4.885376 to Destination: 45.7512988,4.8832373
# Comparing routes from Origin: 45.7376654,4.8851479 to Destination: 45.7595165,4.8467845
# Comparing routes from Origin: 45.7367157,4.8423532 to Destination: 45.7467112,4.7827817
# Comparing routes from Origin: 45.756475,4.8333212 to Destination: 45.7590967,4.8376296
# Comparing routes from Origin: 45.7396805,4.8183976 to Destination: 45.7774282,4.844018
# Comparing routes from Origin: 45.7548579,4.834673 to Destination: 45.7421177,4.8937692
# Comparing routes from Origin: 45.7389827,4.8919902 to Destination: 45.7555602,4.8128243
# Comparing routes from Origin: 45.7736579,4.8069603 to Destination: 45.7702838,4.8122663
# Comparing routes from Origin: 45.7578238,4.8408138 to Destination: 45.7798666,4.8457087
# Comparing routes from Origin: 45.7497245,4.8411203 to Destination: 45.758816,4.8309157
# Comparing routes from Origin: 45.7820621,4.7963118 to Destination: 45.7530779,4.8317444
# Comparing routes from Origin: 45.769255,4.8170372 to Destination: 45.743842,4.8520638
# Comparing routes from Origin: 45.7727929,4.8412816 to Destination: 45.7589992,4.8491751
# Comparing routes from Origin: 45.7462999,4.8383671 to Destination: 45.7652949,4.8479824
# Comparing routes from Origin: 45.7853991,4.8105493 to Destination: 45.7440325,4.8934343
# Comparing routes from Origin: 45.7640665,4.79089 to Destination: 45.7643351,4.8628418
# Comparing routes from Origin: 45.7536792,4.8476633 to Destination: 45.7533899,4.8916212
# Comparing routes from Origin: 45.7451198,4.8628417 to Destination: 45.7653033,4.8019665
# Comparing routes from Origin: 45.7472705,4.8865825 to Destination: 45.7748955,4.8088035
# Comparing routes from Origin: 45.7638389,4.8226983 to Destination: 45.764718,4.8416784
# Comparing routes from Origin: 45.7439664,4.821047 to Destination: 45.76948,4.8523652
# Comparing routes from Origin: 45.7412768,4.8277591 to Destination: 45.7550783,4.8027468
# Comparing routes from Origin: 45.7434171,4.8473956 to Destination: 45.7264642,4.8643441
# Comparing routes from Origin: 45.7717035,4.8467852 to Destination: 45.7510363,4.8846258
# Comparing routes from Origin: 45.7741895,4.8129775 to Destination: 45.7668299,4.8311237
# Comparing routes from Origin: 45.7728622,4.8420855 to Destination: 45.7582282,4.7950489
# Comparing routes from Origin: 45.727427,4.8784468 to Destination: 45.7292688,4.850957
# Comparing routes from Origin: 45.8029628,4.8300379 to Destination: 45.7282637,4.8850668
# Comparing routes from Origin: 45.752845,4.8337608 to Destination: 45.7320799,4.8677042
# Comparing routes from Origin: 45.7943762,4.8153183 to Destination: 45.776382,4.8119895
# Comparing routes from Origin: 45.7510186,4.8437296 to Destination: 45.7516081,4.8327449
# Comparing routes from Origin: 45.7510186,4.8437296 to Destination: 45.7366169,4.8780116
# Comparing routes from Origin: 45.7532003,4.8555569 to Destination: 45.7434554,4.8609411
# Comparing routes from Origin: 45.7781107,4.8442253 to Destination: 45.7534211,4.8413361
# Comparing routes from Origin: 45.8008953,4.8365918 to Destination: 45.7895464,4.8120802
# Comparing routes from Origin: 45.7697184,4.8368553 to Destination: 45.7458729,4.8666075
# Comparing routes from Origin: 45.7882452,4.795398 to Destination: 45.7305197,4.8566624
# Comparing routes from Origin: 45.7538146,4.8440857 to Destination: 45.7476128,4.8639398
# Comparing routes from Origin: 45.748394,4.8516285 to Destination: 45.7396427,4.8621402
# Comparing routes from Origin: 45.7655826,4.8510875 to Destination: 45.7222805,4.8848518
# Comparing routes from Origin: 45.7795337,4.7947871 to Destination: 45.7695372,4.8245104
# Comparing routes from Origin: 45.7428839,4.8505113 to Destination: 45.7742861,4.8308664
# Comparing routes from Origin: 45.7325877,4.8649694 to Destination: 45.7522033,4.8415973
# Comparing routes from Origin: 45.7710248,4.8072173 to Destination: 45.7511146,4.884984
# Comparing routes from Origin: 45.7997072,4.8337188 to Destination: 45.7762326,4.8073102
# Comparing routes from Origin: 45.7848508,4.805817 to Destination: 45.7577017,4.8111759
# Comparing routes from Origin: 45.7518918,4.8273309 to Destination: 45.7541551,4.8672177
# Comparing routes from Origin: 45.7983878,4.823816 to Destination: 45.7440072,4.8242013
# Comparing routes from Origin: 45.7860063,4.8125347 to Destination: 45.7524772,4.7936968
# Comparing routes from Origin: 45.7572745,4.8294473 to Destination: 45.7703794,4.8072191
# Comparing routes from Origin: 45.7508722,4.8591293 to Destination: 45.7620285,4.8638413
# Comparing routes from Origin: 45.7791897,4.841348 to Destination: 45.770267,4.8522008
# Comparing routes from Origin: 45.7702838,4.8122663 to Destination: 45.7644772,4.8460886
# Comparing routes from Origin: 45.7859276,4.785748 to Destination: 45.7665722,4.8112119
# Comparing routes from Origin: 45.7784389,4.8361376 to Destination: 45.7505391,4.8876624
# Comparing routes from Origin: 45.7876758,4.7885658 to Destination: 45.7378325,4.8648442
# Comparing routes from Origin: 45.7585383,4.8510082 to Destination: 45.7342132,4.8365933
# Comparing routes from Origin: 45.7338312,4.8670459 to Destination: 45.7687079,4.8619661
# Comparing routes from Origin: 45.7994574,4.8235787 to Destination: 45.7680449,4.8453793
# Comparing routes from Origin: 45.7637773,4.8459792 to Destination: 45.748861,4.8302771
# Comparing routes from Origin: 45.7468805,4.7892411 to Destination: 45.7282862,4.8441712
# Comparing routes from Origin: 45.7741485,4.8423019 to Destination: 45.7524735,4.7933074
# Comparing routes from Origin: 45.7427781,4.850546 to Destination: 45.7357228,4.8276234
# Comparing routes from Origin: 45.7502853,4.8245926 to Destination: 45.7672792,4.8367579
# Comparing routes from Origin: 45.7494273,4.8310721 to Destination: 45.7717827,4.8414272
# Comparing routes from Origin: 45.7716377,4.8277307 to Destination: 45.7656472,4.7923461
# Comparing routes from Origin: 45.7790772,4.8413016 to Destination: 45.7246212,4.886166
# Comparing routes from Origin: 45.7462011,4.8459813 to Destination: 45.7342132,4.8365933
# Comparing routes from Origin: 45.7709755,4.8520702 to Destination: 45.7725415,4.8566022
# Comparing routes from Origin: 45.7578116,4.8129741 to Destination: 45.7474732,4.8899719
# Comparing routes from Origin: 45.7678446,4.8130939 to Destination: 45.7496615,4.8651052
# Comparing routes from Origin: 45.754893,4.8756285 to Destination: 45.7534211,4.8413361
# Comparing routes from Origin: 45.7983116,4.8210624 to Destination: 45.7943762,4.8153183
# Comparing routes from Origin: 45.7419204,4.8437943 to Destination: 45.7512682,4.8898704
# Comparing routes from Origin: 45.7699336,4.8570651 to Destination: 45.7669467,4.8464148
# Comparing routes from Origin: 45.7699831,4.8124735 to Destination: 45.7436778,4.8579822
# Comparing routes from Origin: 45.760929,4.804297 to Destination: 45.754893,4.8756285
# Comparing routes from Origin: 45.7322673,4.86412 to Destination: 45.7520696,4.8208984
# Comparing routes from Origin: 45.730623,4.8698359 to Destination: 45.7473069,4.8479935
# Comparing routes from Origin: 45.7730417,4.8067373 to Destination: 45.7406607,4.8514385
# Comparing routes from Origin: 45.7569628,4.8460545 to Destination: 45.7594725,4.8709448
# Comparing routes from Origin: 45.7361985,4.8862566 to Destination: 45.7433254,4.8381994
# Comparing routes from Origin: 45.7376654,4.8851479 to Destination: 45.7574224,4.8546299
# Comparing routes from Origin: 45.7761891,4.8222171 to Destination: 45.7367927,4.831748
# Comparing routes from Origin: 45.7282623,4.834755 to Destination: 45.7893228,4.8005939
# Comparing routes from Origin: 45.7703219,4.8219055 to Destination: 45.7847585,4.8085932
# Comparing routes from Origin: 45.7475571,4.829905 to Destination: 45.7727826,4.8465804
# Comparing routes from Origin: 45.7750341,4.8071959 to Destination: 45.7490865,4.8878197
# Comparing routes from Origin: 45.7439841,4.8477286 to Destination: 45.7266206,4.8685253
# Comparing routes from Origin: 45.7893228,4.8005939 to Destination: 45.7635883,4.8430023
# Comparing routes from Origin: 45.7423604,4.8507079 to Destination: 45.7703085,4.8009701
# Comparing routes from Origin: 45.7741895,4.8129775 to Destination: 45.755422,4.8616195
# Comparing routes from Origin: 45.748394,4.8516285 to Destination: 45.7550026,4.8591368
# Comparing routes from Origin: 45.7735051,4.8451743 to Destination: 45.7651564,4.8627558
# Comparing routes from Origin: 45.7773569,4.8284039 to Destination: 45.7329674,4.8738834
# Comparing routes from Origin: 45.7795324,4.8290867 to Destination: 45.7270701,4.8695132
# Comparing routes from Origin: 45.7597264,4.8709281 to Destination: 45.7898178,4.8120239
# Comparing routes from Origin: 45.7446811,4.8791623 to Destination: 45.7475363,4.8463158
# Comparing routes from Origin: 45.7760936,4.832964 to Destination: 45.7565012,4.8411017
# Comparing routes from Origin: 45.7256472,4.8765013 to Destination: 45.7599841,4.8665819
# Comparing routes from Origin: 45.7536622,4.8593929 to Destination: 45.7539528,4.8256976
# Comparing routes from Origin: 45.7649495,4.8513333 to Destination: 45.7730472,4.8066764
# Comparing routes from Origin: 45.7507306,4.8142214 to Destination: 45.7513727,4.8292421
# Comparing routes from Origin: 45.74949,4.8597276 to Destination: 45.7744052,4.8450095
# Comparing routes from Origin: 45.7680402,4.8028505 to Destination: 45.7648759,4.8350926
# Comparing routes from Origin: 45.7449833,4.8486426 to Destination: 45.7873216,4.807987
# Comparing routes from Origin: 45.7588319,4.8659945 to Destination: 45.7654782,4.8570684
# Comparing routes from Origin: 45.76948,4.8523652 to Destination: 45.7869256,4.7864179
# Comparing routes from Origin: 45.7549953,4.8568408 to Destination: 45.7692109,4.8293733
# Comparing routes from Origin: 45.769114,4.7912346 to Destination: 45.7492136,4.875591
# Comparing routes from Origin: 45.7390424,4.8665224 to Destination: 45.8066011,4.8377709
# Comparing routes from Origin: 45.7816158,4.8370954 to Destination: 45.7761102,4.8435104
# Comparing routes from Origin: 45.7501683,4.8316125 to Destination: 45.7477448,4.8634284
# Comparing routes from Origin: 45.7702416,4.8363614 to Destination: 45.7527156,4.828083
# Comparing routes from Origin: 45.7927798,4.8194223 to Destination: 45.7674524,4.7985564
# Comparing routes from Origin: 45.7565012,4.8411017 to Destination: 45.7361684,4.8800138
# Comparing routes from Origin: 45.7607261,4.8340421 to Destination: 45.7863321,4.790469
# Comparing routes from Origin: 45.7278218,4.8240423 to Destination: 45.7580776,4.8675678
# Comparing routes from Origin: 45.759226,4.8264309 to Destination: 45.7728176,4.8054306
# Comparing routes from Origin: 45.7509371,4.781537 to Destination: 45.7602758,4.8340177
# Comparing routes from Origin: 45.7852958,4.807926 to Destination: 45.7588028,4.810695
# Comparing routes from Origin: 45.7333739,4.8160592 to Destination: 45.7750341,4.8071959
# Comparing routes from Origin: 45.7570732,4.8586532 to Destination: 45.7318633,4.8518581
# Comparing routes from Origin: 45.7493129,4.8594748 to Destination: 45.7659167,4.8557941
# Comparing routes from Origin: 45.7509728,4.8811825 to Destination: 45.7374436,4.8292473
# Comparing routes from Origin: 45.7730012,4.8489341 to Destination: 45.7459237,4.8395283
# Comparing routes from Origin: 45.7391914,4.8291251 to Destination: 45.7371063,4.8503395
# Comparing routes from Origin: 45.7536063,4.8837541 to Destination: 45.7517348,4.8148227
# Comparing routes from Origin: 45.7515111,4.8906149 to Destination: 45.7473442,4.8650544
# Comparing routes from Origin: 45.7863698,4.7968624 to Destination: 45.7774244,4.8443497
# Comparing routes from Origin: 45.7747388,4.8255939 to Destination: 45.7719513,4.8548067
# Comparing routes from Origin: 45.745655,4.8359796 to Destination: 45.7594417,4.8697263
# Comparing routes from Origin: 45.7605567,4.8378008 to Destination: 45.748185,4.8295178
# Comparing routes from Origin: 45.758329,4.8478365 to Destination: 45.7647887,4.8290886
# Comparing routes from Origin: 45.7534995,4.8392583 to Destination: 45.7687528,4.8631618
# Comparing routes from Origin: 45.7529029,4.8422445 to Destination: 45.7406086,4.8833518
# Comparing routes from Origin: 45.776382,4.8119895 to Destination: 45.7266008,4.8335831
# Comparing routes from Origin: 45.7637343,4.8026396 to Destination: 45.7251827,4.8817434
# Comparing routes from Origin: 45.7520581,4.7820991 to Destination: 45.7434152,4.8653524
# Comparing routes from Origin: 45.7305197,4.8566624 to Destination: 45.7516735,4.894945
# Comparing routes from Origin: 45.7620666,4.8214752 to Destination: 45.7745465,4.8069779
# Comparing routes from Origin: 45.7662421,4.8592204 to Destination: 45.7678982,4.858102
# Comparing routes from Origin: 45.752621,4.831429 to Destination: 45.7716053,4.8356654
# Comparing routes from Origin: 45.7791572,4.8159226 to Destination: 45.7565267,4.8361136
# Comparing routes from Origin: 45.7574244,4.8180368 to Destination: 45.7498761,4.8684721
# Comparing routes from Origin: 45.767796,4.8314259 to Destination: 45.7756417,4.8027437
# Comparing routes from Origin: 45.7859276,4.785748 to Destination: 45.7366107,4.8339816
# Comparing routes from Origin: 45.7549597,4.8783352 to Destination: 45.7720322,4.8266753
# Comparing routes from Origin: 45.7636528,4.7955464 to Destination: 45.7678446,4.8130939
# Comparing routes from Origin: 45.7371669,4.8836662 to Destination: 45.7639786,4.8459303
# Comparing routes from Origin: 45.7720223,4.8180606 to Destination: 45.7780088,4.8347901
# Comparing routes from Origin: 45.7802155,4.834478 to Destination: 45.7311662,4.8660774
# Comparing routes from Origin: 45.7313063,4.8335984 to Destination: 45.7489981,4.8300349
# Comparing routes from Origin: 45.7651804,4.8314758 to Destination: 45.7672982,4.8633222
# Comparing routes from Origin: 45.746837,4.8420941 to Destination: 45.7338862,4.8427189
# Comparing routes from Origin: 45.7736522,4.8213576 to Destination: 45.751548,4.8410526
# Comparing routes from Origin: 45.722439,4.8849898 to Destination: 45.7520581,4.7820991
# Comparing routes from Origin: 45.7560983,4.8528742 to Destination: 45.7533007,4.8563887
# Comparing routes from Origin: 45.7234897,4.8794931 to Destination: 45.7754373,4.8469097
# Comparing routes from Origin: 45.7852021,4.8088469 to Destination: 45.7964896,4.8168307
# Comparing routes from Origin: 45.7734741,4.8004228 to Destination: 45.7495859,4.8526198
# Comparing routes from Origin: 45.7783984,4.8322404 to Destination: 45.7704072,4.8257203
# Comparing routes from Origin: 45.7852958,4.807926 to Destination: 45.7765709,4.832321
# Comparing routes from Origin: 45.7646541,4.8481094 to Destination: 45.7537061,4.8597903
# Comparing routes from Origin: 45.7536908,4.8894822 to Destination: 45.7486046,4.8478059
# Comparing routes from Origin: 45.7424298,4.8402232 to Destination: 45.7518775,4.8712228
# Comparing routes from Origin: 45.7761102,4.8435104 to Destination: 45.7690854,4.83822
# Comparing routes from Origin: 45.7500177,4.8513535 to Destination: 45.7958265,4.819905
# Comparing routes from Origin: 45.7629247,4.8341684 to Destination: 45.7671973,4.864795
# Comparing routes from Origin: 45.7721712,4.8518307 to Destination: 45.7453645,4.8481102
# Comparing routes from Origin: 45.7470863,4.8623656 to Destination: 45.7479128,4.8478993
# Comparing routes from Origin: 45.7496972,4.8466386 to Destination: 45.7593206,4.8316206
# Comparing routes from Origin: 45.7768263,4.807738 to Destination: 45.7517402,4.8428925
# Comparing routes from Origin: 45.7899053,4.8113232 to Destination: 45.7517803,4.8213888
# Comparing routes from Origin: 45.754619,4.8257354 to Destination: 45.7644772,4.8460886
# Comparing routes from Origin: 45.7544037,4.7827359 to Destination: 45.7451452,4.8466265
# Comparing routes from Origin: 45.764718,4.8416784 to Destination: 45.7453645,4.8481102
# Comparing routes from Origin: 45.7518674,4.8916989 to Destination: 45.7673997,4.8647924
# Comparing routes from Origin: 45.7623704,4.8075135 to Destination: 45.7227204,4.8428873
# Comparing routes from Origin: 45.7714333,4.8519736 to Destination: 45.7725712,4.8443017
# Comparing routes from Origin: 45.7771984,4.8322288 to Destination: 45.7744052,4.8450095
# Comparing routes from Origin: 45.7340764,4.8394217 to Destination: 45.7658193,4.8478826
# Comparing routes from Origin: 45.7741485,4.8423019 to Destination: 45.7491541,4.821945
# Comparing routes from Origin: 45.7445686,4.8437974 to Destination: 45.7241663,4.8757622
# Comparing routes from Origin: 45.754831,4.796148 to Destination: 45.7580404,4.8338067
# Comparing routes from Origin: 45.739522,4.8524937 to Destination: 45.7717721,4.8382538
# Comparing routes from Origin: 45.7831925,4.8105244 to Destination: 45.7627355,4.807913

# %%
import pandas as pd
from tabulate import tabulate

# Read the CSV file
df = pd.read_csv('/content/route_comparison_results.csv')

# Print the DataFrame in a tabular format using tabulate
print(tabulate(df, headers='keys', tablefmt='pretty'))
# Out:
# +-----+----------------------------+-----------------------------+---------------------------+---------------------------------+----------------------------------+
# |     | Fastest Route Energy (kWh) | Shortest Route Energy (kWh) | Custom Route Energy (kWh) | Savings Compared to Fastest (%) | Savings Compared to Shortest (%) |
# +-----+----------------------------+-----------------------------+---------------------------+---------------------------------+----------------------------------+
# |  0  |   8.221936016399411e-05    |    8.221936016399411e-05    |   7.694663304629837e-05   |        6.412999453144364        |        6.412999453144364         |
# |  1  |   3.4470736212140154e-05   |    4.103554382686221e-05    |   2.561001871998642e-05   |        25.70504278650452        |        37.59064378910001         |
# |  2  |   4.486623187537556e-05    |    4.486623187537556e-05    |  1.7560459221502802e-05   |        60.86040996203938        |        60.86040996203938         |
# |  3  |     0.0002145389502203     |     0.0002094219544301      |    0.0001662016800689     |       22.530766605169138        |        20.637890845191954        |
# |  4  |   5.872395796740136e-05    |    5.872395796740136e-05    |   6.025569210486331e-05   |       -2.6083632481179952       |       -2.6083632481179952        |
# |  5  |   4.115108011573157e-05    |    4.115108011573157e-05    |   3.604147611361936e-05   |       12.416694744687574        |        12.416694744687574        |
# |  6  |     0.000151089605655      |     0.0001165306763152      |    0.0001216345932346     |       19.495062080983484        |        -4.379891270552561        |
# |  7  |     0.0001723313978213     |      0.000149150864412      |     0.000148303723801     |       13.942714052124703        |        0.5679756629396571        |
# |  8  |     0.0001293786330634     |     0.0001229914891101      |   7.366493694175125e-05   |       43.062517204330085        |        40.10566302211666         |
# |  9  |   7.372243852170442e-05    |    7.592800233573699e-05    |   7.756288165585717e-05   |       -5.2093273244374405       |        -2.153196804640145        |
# | 10  |   4.694618706963349e-05    |    4.644853526670666e-05    |   4.567551877563545e-05   |       2.7066485551069497        |        1.6642429877122389        |
# | 11  |     0.0001955740407376     |     0.0001345045113249      |    0.0001151835866714     |        41.10486942078047        |        14.36451793557776         |
# | 12  |     0.0004832039797752     |     0.0001529052766656      |    0.0001454708830031     |        69.89451885913552        |        4.862090978562172         |
# | 13  |     0.0001908238474861     |     0.0001633189777474      |    0.0001291150193706     |       32.338111262518495        |        20.943039718054024        |
# | 14  |     0.0001338080832776     |    9.522879822010493e-05    |   7.180442394481786e-05   |        46.33775315664415        |        24.59799421299601         |
# | 15  |   1.1086920231660105e-05   |   1.1086920231660105e-05    |   8.259212199451078e-06   |        25.50490102863865        |        25.50490102863865         |
# | 178 |   2.5481781657915053e-05   |   2.5481781657915053e-05    |   2.406494852611852e-05   |        5.560180802178872        |        5.560180802178872         |
# | 179 |    9.76584601541274e-05    |    9.76584601541274e-05     |   7.54040472649629e-05    |       22.788003060914484        |        22.788003060914484        |
# | 180 |   3.337487408434328e-05    |    3.337487408434328e-05    |  4.1761062663762656e-05   |       -25.127251591200704       |       -25.127251591200704        |
# | 181 |   1.3831947647362109e-05   |   1.3831947647362109e-05    |  1.7526839828396697e-05   |       -26.71273977630506        |        -26.71273977630506        |
# | 182 |   9.282701109235328e-05    |    8.038799173748039e-05    |   8.341471301689018e-05   |       10.139611266917592        |       -3.7651410540196384        |
# | 183 |   7.862357720145419e-05    |    6.846013052888042e-05    |   7.077208246791689e-05   |        9.986183550793823        |        -3.377077900926806        |
# | 184 |     0.0002338923855577     |     0.0001588261458287      |    0.0001215182597199     |       48.045226256434304        |        23.489763548755583        |
# | 185 |   8.136177563905514e-05    |    6.490785041060719e-05    |   6.024554830976755e-05   |       25.953498634254743        |        7.182955638410316         |
# | 186 |     0.0004051670498972     |     0.0001538425435983      |    0.0001308159212079     |        67.71308988695905        |        14.96765579387338         |
# | 187 |     0.0001084363437299     |     0.0001049572853945      |   9.257798881272553e-05   |       14.624575462168298        |        11.794604381489382        |
# | 188 |     0.0002113762265211     |     0.0001380891542653      |   7.309200781708544e-05   |        65.42089476188777        |        47.06897279083887         |
# | 189 |   9.550208251480208e-06    |    9.550208251480208e-06    |   9.662504842154148e-06   |       -1.1758548894107657       |       -1.1758548894107657        |
# | 190 |   3.6480716682684325e-05   |   3.6480716682684325e-05    |   2.355197482994185e-05   |        35.43993382914853        |        35.43993382914853         |
# | 191 |     0.0001266700054668     |    9.506619956196708e-05    |   6.988469407048591e-05   |        44.82932734320612        |        26.48838978260312         |
# | 192 |     0.0001144398473507     |     0.0001144398473507      |   8.17041733510369e-05    |       28.605136023428845        |        28.605136023428845        |
# | 193 |   7.716368142443292e-05    |    6.241045074763188e-05    |   4.570583265330775e-05   |        40.76768784279962        |        26.76573858098273         |
# | 194 |     0.0004152653300315     |     0.0001249195174536      |    0.0001212636750473     |        70.79850729699042        |        2.926558219905828         |
# | 195 |     0.0001008959711518     |    9.773710695456608e-05    |   8.268172473778125e-05   |       18.052501211043197        |        15.403957295138127        |
# | 196 |   9.836718761246792e-05    |    9.836718761246792e-05    |   8.630200954015313e-05   |        12.26544985696586        |        12.26544985696586         |
# | 197 |   4.5436566887475225e-05   |   4.5436566887475225e-05    |   3.830551700965625e-05   |       15.694517359727456        |        15.694517359727456        |
# | 198 |     0.0001175292767171     |    9.321441479620442e-05    |   6.543449285918483e-05   |        44.32494210216446        |        29.80217383518965         |
# | 199 |    9.1432837925973e-05     |    5.805488731172213e-05    |   5.105629025356965e-05   |        44.15978830832476        |        12.055138477100035        |
# +-----+----------------------------+-----------------------------+---------------------------+---------------------------------+----------------------------------+

# %% [markdown]
# ### Visualization of the results

# %%
import pandas as pd
import matplotlib.pyplot as plt
from tabulate import tabulate

# Read the CSV file
df = pd.read_csv('/content/route_comparison_results.csv')

# Calculate the average of the two columns for each row
df['Average Savings (%)'] = df[['Savings Compared to Fastest (%)', 'Savings Compared to Shortest (%)']].mean(axis=1)

# Calculate the total average savings
total_average_savings = df['Average Savings (%)'].mean()
average_savings_fastest = df['Savings Compared to Fastest (%)'].mean()
average_savings_shortest = df['Savings Compared to Shortest (%)'].mean()



# Print the total average savings
print(f"\nTotal Average Savings (%): {total_average_savings:.2f}")
print(f"Average Savings Compared to Fastest (%): {average_savings_fastest:.2f}")
print(f"Average Savings Compared to Shortest (%): {average_savings_shortest:.2f}")

# Plot the data
plt.figure(figsize=(20, 6))
plt.plot(df.index, df['Savings Compared to Fastest (%)'], label='Savings Compared to Fastest (%)', marker='o')
plt.plot(df.index, df['Savings Compared to Shortest (%)'], label='Savings Compared to Shortest (%)', marker='x')
plt.plot(df.index, df['Average Savings (%)'], label='Average Savings (%)', marker='s')

# Add titles and labels
plt.title('Savings Comparison')
plt.xlabel('Index')
plt.ylabel('Savings (%)')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
# Out:
# Total Average Savings (%): 17.62
# Average Savings Compared to Fastest (%): 23.33
# Average Savings Compared to Shortest (%): 11.91

# %% [markdown]
# ## Visualization with some fault tolerance

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from tabulate import tabulate


FAULT_TOLERANCE_PERCENT = 30


df = pd.read_csv('/content/route_comparison_results.csv')


df['Average Savings (%)'] = df[['Savings Compared to Fastest (%)', 'Savings Compared to Shortest (%)']].mean(axis=1)

upper_bound = np.percentile(df['Average Savings (%)'], 100 - FAULT_TOLERANCE_PERCENT)
filtered_df = df[df['Average Savings (%)'] <= upper_bound]


total_average_savings = filtered_df['Average Savings (%)'].mean()
average_savings_fastest = filtered_df['Savings Compared to Fastest (%)'].mean()
average_savings_shortest = filtered_df['Savings Compared to Shortest (%)'].mean()


print(f"\nTotal Average Savings (%): {total_average_savings:.2f}")
print(f"Average Savings Compared to Fastest (%): {average_savings_fastest:.2f}")
print(f"Average Savings Compared to Shortest (%): {average_savings_shortest:.2f}")

plt.figure(figsize=(20, 6))
plt.plot(filtered_df.index, filtered_df['Savings Compared to Fastest (%)'], label='Savings Compared to Fastest (%)', marker='o')
plt.plot(filtered_df.index, filtered_df['Savings Compared to Shortest (%)'], label='Savings Compared to Shortest (%)', marker='x')
plt.plot(filtered_df.index, filtered_df['Average Savings (%)'], label='Average Savings (%)', marker='s')


plt.title(f'Savings Comparison (With Fault Tolerance of {FAULT_TOLERANCE_PERCENT}%)')
plt.xlabel('Index')
plt.ylabel('Savings (%)')
plt.legend()
plt.grid(True)

plt.show()
# Out:
# Total Average Savings (%): 8.00
# Average Savings Compared to Fastest (%): 11.77
# Average Savings Compared to Shortest (%): 4.24

# %%
import pandas as pd
import matplotlib.pyplot as plt
from tabulate import tabulate

# Read the CSV file
df = pd.read_csv('/content/route_comparison_results.csv')

# Calculate new metrics
df['Average Savings (%)'] = df[['Savings Compared to Fastest (%)', 'Savings Compared to Shortest (%)']].mean(axis=1)

# Total averages
total_average_savings = df['Average Savings (%)'].mean()
average_savings_fastest = df['Savings Compared to Fastest (%)'].mean()
average_savings_shortest = df['Savings Compared to Shortest (%)'].mean()

# Compute cumulative savings (total impact over time)
df['Cumulative Savings (%)'] = df['Average Savings (%)'].cumsum()

# Compute relative percentage increase/decrease in energy consumption
df['% Increase from Fastest'] = ((df['Custom Route Energy (kWh)'] - df['Fastest Route Energy (kWh)']) / df['Fastest Route Energy (kWh)']) * 100
df['% Increase from Shortest'] = ((df['Custom Route Energy (kWh)'] - df['Shortest Route Energy (kWh)']) / df['Shortest Route Energy (kWh)']) * 100

# Print the total average savings
print(f"\nTotal Average Savings (%): {total_average_savings:.2f}")
print(f"Average Savings Compared to Fastest (%): {average_savings_fastest:.2f}")
print(f"Average Savings Compared to Shortest (%): {average_savings_shortest:.2f}")

# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(20, 12))

# 1. Savings Comparison Over Time
axes[0, 0].plot(df.index, df['Savings Compared to Fastest (%)'], label='Savings Compared to Fastest (%)', marker='o', linestyle='--')
axes[0, 0].plot(df.index, df['Savings Compared to Shortest (%)'], label='Savings Compared to Shortest (%)', marker='x', linestyle='--')
axes[0, 0].plot(df.index, df['Average Savings (%)'], label='Average Savings (%)', marker='s', linestyle='-')
axes[0, 0].set_title('Savings Comparison Over Time')
axes[0, 0].set_xlabel('Index')
axes[0, 0].set_ylabel('Savings (%)')
axes[0, 0].legend()
axes[0, 0].grid(True)

# 2. Energy Consumption Comparison
axes[0, 1].plot(df.index, df['Fastest Route Energy (kWh)'], label='Fastest Route Energy (kWh)', marker='o')
axes[0, 1].plot(df.index, df['Shortest Route Energy (kWh)'], label='Shortest Route Energy (kWh)', marker='x')
axes[0, 1].plot(df.index, df['Custom Route Energy (kWh)'], label='Custom Route Energy (kWh)', marker='s')
axes[0, 1].set_title('Energy Consumption Comparison')
axes[0, 1].set_xlabel('Index')
axes[0, 1].set_ylabel('Energy (kWh)')
axes[0, 1].legend()
axes[0, 1].grid(True)

# 3. Cumulative Savings Over Time
axes[1, 0].plot(df.index, df['Cumulative Savings (%)'], label='Cumulative Savings (%)', marker='s', color='purple')
axes[1, 0].set_title('Cumulative Energy Savings')
axes[1, 0].set_xlabel('Index')
axes[1, 0].set_ylabel('Cumulative Savings (%)')
axes[1, 0].legend()
axes[1, 0].grid(True)

# 4. Percentage Increase in Energy Consumption
axes[1, 1].plot(df.index, df['% Increase from Fastest'], label='% Increase from Fastest', marker='o', linestyle='--', color='red')
axes[1, 1].plot(df.index, df['% Increase from Shortest'], label='% Increase from Shortest', marker='x', linestyle='--', color='blue')
axes[1, 1].set_title('Percentage Increase in Energy Consumption')
axes[1, 1].set_xlabel('Index')
axes[1, 1].set_ylabel('Increase (%)')
axes[1, 1].legend()
axes[1, 1].grid(True)

# Adjust layout and show plots
plt.tight_layout()
plt.show()
# Out:
# Total Average Savings (%): 17.62
# Average Savings Compared to Fastest (%): 23.33
# Average Savings Compared to Shortest (%): 11.91
